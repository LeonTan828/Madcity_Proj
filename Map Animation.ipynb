# %%
# %matplotlib inline

# %%
import pandas as pd
import geopandas # we'll use this to read shapefiles
from shapely.geometry import Polygon, Point
from matplotlib import pyplot as plt
from matplotlib import animation
from IPython.display import HTML

# %%
# %%capture
fig, ax = plt.subplots(figsize = (12,10))

# %%
#city = geopandas.read_file("city")
#lakes = geopandas.read_file("lakes")

def update_func(frame_num):
    # each time this gets called, we compute new coordinates based on frame_num
    points = pd.DataFrame([
        {"loc": Point(-89.406749 + frame_num/100, 43.071478)},
        {"loc": Point(-89.384054, 43.074617 + frame_num/100)},
    ])
    points = geopandas.GeoDataFrame(points, geometry="loc")

    ax.cla() # clears plot area (try removing it!)
    #city.plot(color="lightgray", ax=ax)
    #lakes.plot(color="darkgray", ax=ax)
    points.plot(color="black", marker="x", markersize=200, ax=ax)
    ax.set_axis_off()
    
    if frame_num > 10:
        ax.text(-89.384054, 43.074617, "bye!")

HTML(animation.FuncAnimation(fig, update_func, frames=15, interval=200).to_html5_video())
# Out:
# <video width="864" height="720" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %%
points = pd.DataFrame([
        {"loc": Point(-89.406749, 43.071478)},
        {"loc": Point(-89.384054, 43.074617)},
    ])
points
# Out:
#                                     loc
# 0          POINT (-89.406749 43.071478)
# 1  POINT (-89.38405400000001 43.074617)

# %%
points.loc[2] = {"loc": Point(-89.384054, 43.074617)}

# %%
points = pd.DataFrame(columns=['loc'])

# %%
points.loc[0] = {"loc": Point(-89.384054, 43.074617)}
points.loc[1] = {"loc": Point(-89.384054, 43.074617)}
points.loc[2] = {"loc": Point(-89.384054, 43.074617)}

# %%
weap2018 = pd.read_csv("WeaponVio2018.csv")

xVals = list(weap2018["Longitude"])
yVals = list(weap2018["Latitude"])
i = 0

for xVal, yVal in zip(xVals, yVals):
    points.loc[i] = {"loc": Point(xVals[i], yVals[i])}
    i += 1

# %%
points
# Out:
#                                               loc
# 0    POINT (-89.29473203816357 43.03658529525269)
# 1     POINT (-89.3636003630337 43.09462722514773)
# 2    POINT (-89.39775899050498 43.14171060002911)
# 3    POINT (-89.31984202553522 43.06208650894319)
# 4    POINT (-89.38304758102012 43.13958749681792)
# 5    POINT (-89.50318497145734 43.01983788923326)
# 6    POINT (-89.30508683288021 43.09202058355989)
# 7    POINT (-89.39412899999998 43.04890207449485)
# 8    POINT (-89.45130991087437 43.07389941665263)
# 9    POINT (-89.52454213210916 43.06648788806967)
# 10    POINT (-89.48670982966067 43.0464029681343)
# 11   POINT (-89.38292888129759 43.07207946658759)
# 12   POINT (-89.38868736766054 43.06852207688583)
# 13   POINT (-89.40032663818052 43.14139904776776)
# 14   POINT (-89.44673562595234 43.03273006016114)
# 15   POINT (-89.38292888129759 43.07207946658759)
# 16   POINT (-89.32682066960274 43.09335972324921)
# 17   POINT (-89.35116069532219 43.10930415607965)
# 18   POINT (-89.39417610430435 43.04473213627446)
# 19    POINT (-89.36795373439881 43.0782632469697)
# 20   POINT (-89.47299483601488 43.07788142222025)
# 21   POINT (-89.38292888129759 43.07207946658759)
# 22    POINT (-89.4723828466213 43.03199669615304)
# 23    POINT (-89.5025433286245 43.07516044443361)
# 24    POINT (-89.30012918499081 43.1383209632484)
# 25   POINT (-89.39277051802088 43.04974559825997)
# 26   POINT (-89.34459705228254 43.10297479623781)
# 27   POINT (-89.38707202553522 43.07468346681873)
# 28   POINT (-89.35518109393965 43.12099605680832)
# 29   POINT (-89.31984202553522 43.06208650894319)
# ..                                            ...
# 186  POINT (-89.40347913825167 43.15234564234142)
# 187  POINT (-89.41656594507461 43.03280407694104)
# 188  POINT (-89.39007602701089 43.07486184404767)
# 189  POINT (-89.29427284829792 43.08751428619831)
# 190  POINT (-89.38720971681394 43.13384672861378)
# 191  POINT (-89.40088558814686 43.06165149708582)
# 192  POINT (-89.51971382967487 43.06383276123297)
# 193  POINT (-89.40097504585751 43.07099901747361)
# 194   POINT (-89.35673841316404 43.1338251665039)
# 195  POINT (-89.38379510634195 43.13382525811043)
# 196   POINT (-89.36605909204201 43.1252640313636)
# 197  POINT (-89.38242521559503 43.07758935825701)
# 198  POINT (-89.36889303342298 43.08139420188284)
# 199  POINT (-89.36347474799055 43.09557538777377)
# 200  POINT (-89.39070910670944 43.04432503153471)
# 201          POINT (-89.40733875000002 43.072785)
# 202  POINT (-89.42227787315839 43.02990189159286)
# 203  POINT (-89.32686526146905 43.11557679268846)
# 204  POINT (-89.49364357215117 43.03171300802415)
# 205  POINT (-89.38221849097874 43.07883117144121)
# 206  POINT (-89.39009333276941 43.07477174954894)
# 207  POINT (-89.47365493699266 43.04642527901294)
# 208  POINT (-89.52291731089625 43.05671649807578)
# 209   POINT (-89.35173990780814 43.0928190774051)
# 210   POINT (-89.37357585633883 43.1483088869682)
# 211  POINT (-89.39081427651989 43.07800398997411)
# 212  POINT (-89.32159270642883 43.06210286500388)
# 213  POINT (-89.39081427651989 43.07800398997411)
# 214  POINT (-89.33401265281415 43.10794620836391)
# 215   POINT (-89.38670602410723 43.0783981356353)
#
# [216 rows x 1 columns]

# %%
points2018 = pd.DataFrame(columns=['loc'])

weap2018 = pd.read_csv("WeaponVio2018.csv")

xVals = list(weap2018["Longitude"])
yVals = list(weap2018["Latitude"])
i = 0

for xVal, yVal in zip(xVals, yVals):
    points2018.loc[i] = {"loc": Point(xVals[i], yVals[i])}
    i += 1
    
    
points2017 = pd.DataFrame(columns=['loc'])

weap2017 = pd.read_csv("WeaponVio2017.csv")

xVals = list(weap2017["Longitude"])
yVals = list(weap2017["Latitude"])
i = 0

for xVal, yVal in zip(xVals, yVals):
    points2017.loc[i] = {"loc": Point(xVals[i], yVals[i])}
    i += 1
    

points2016 = pd.DataFrame(columns=['loc'])

weap2016 = pd.read_csv("WeaponVio2016.csv")

xVals = list(weap2016["Longitude"])
yVals = list(weap2016["Latitude"])
i = 0

for xVal, yVal in zip(xVals, yVals):
    points2016.loc[i] = {"loc": Point(xVals[i], yVals[i])}
    i += 1
    
    
points2015 = pd.DataFrame(columns=['loc'])

weap2015 = pd.read_csv("WeaponVio2015.csv")

xVals = list(weap2015["Longitude"])
yVals = list(weap2015["Latitude"])
i = 0

for xVal, yVal in zip(xVals, yVals):
    points2015.loc[i] = {"loc": Point(xVals[i], yVals[i])}
    i += 1
    
    
points2014 = pd.DataFrame(columns=['loc'])

weap2014 = pd.read_csv("WeaponVio2014.csv")

xVals = list(weap2014["Longitude"])
yVals = list(weap2014["Latitude"])
i = 0

for xVal, yVal in zip(xVals, yVals):
    points2014.loc[i] = {"loc": Point(xVals[i], yVals[i])}
    i += 1
    
    
points2013 = pd.DataFrame(columns=['loc'])

weap2013 = pd.read_csv("WeaponVio2013.csv")

xVals = list(weap2013["Longitude"])
yVals = list(weap2013["Latitude"])
i = 0

for xVal, yVal in zip(xVals, yVals):
    points2013.loc[i] = {"loc": Point(xVals[i], yVals[i])}
    i += 1
    
    
points2012 = pd.DataFrame(columns=['loc'])

weap2012 = pd.read_csv("WeaponVio2012.csv")

xVals = list(weap2012["Longitude"])
yVals = list(weap2012["Latitude"])
i = 0

for xVal, yVal in zip(xVals, yVals):
    points2012.loc[i] = {"loc": Point(xVals[i], yVals[i])}
    i += 1
    
    
points2011 = pd.DataFrame(columns=['loc'])

weap2011 = pd.read_csv("WeaponVio2011.csv")

xVals = list(weap2011["Longitude"])
yVals = list(weap2011["Latitude"])
i = 0

for xVal, yVal in zip(xVals, yVals):
    points2011.loc[i] = {"loc": Point(xVals[i], yVals[i])}
    i += 1
    
    
points2010 = pd.DataFrame(columns=['loc'])

weap2010 = pd.read_csv("WeaponVio2010.csv")

xVals = list(weap2010["Longitude"])
yVals = list(weap2010["Latitude"])
i = 0

for xVal, yVal in zip(xVals, yVals):
    points2010.loc[i] = {"loc": Point(xVals[i], yVals[i])}
    i += 1
    
    
points2009 = pd.DataFrame(columns=['loc'])

weap2009 = pd.read_csv("WeaponVio2009.csv")

xVals = list(weap2009["Longitude"])
yVals = list(weap2009["Latitude"])
i = 0

for xVal, yVal in zip(xVals, yVals):
    points2009.loc[i] = {"loc": Point(xVals[i], yVals[i])}
    i += 1
    
    
points2008 = pd.DataFrame(columns=['loc'])

weap2008 = pd.read_csv("WeaponVio2008.csv")

xVals = list(weap2008["Longitude"])
yVals = list(weap2008["Latitude"])
i = 0

for xVal, yVal in zip(xVals, yVals):
    points2008.loc[i] = {"loc": Point(xVals[i], yVals[i])}
    i += 1

# %%
# my version

city = geopandas.read_file("city")
lakes = geopandas.read_file("lakes")



def update_func(frame_num):
    
    if frame_num == 0:
        points = geopandas.GeoDataFrame(points2008, geometry="loc")
        year = 2008
    elif frame_num == 1:
        points = geopandas.GeoDataFrame(points2009, geometry="loc")
        year = 2009
    elif frame_num == 2:
        points = geopandas.GeoDataFrame(points2010, geometry="loc")
        year = 2010
    elif frame_num == 3:
        points = geopandas.GeoDataFrame(points2011, geometry="loc")
        year = 2011
    elif frame_num == 4:
        points = geopandas.GeoDataFrame(points2012, geometry="loc")
        year = 2012
    elif frame_num == 5:
        points = geopandas.GeoDataFrame(points2013, geometry="loc")
        year = 2013
    elif frame_num == 6:
        points = geopandas.GeoDataFrame(points2014, geometry="loc")
        year = 2014
    elif frame_num == 7:
        points = geopandas.GeoDataFrame(points2015, geometry="loc")
        year = 2015
    elif frame_num == 8:
        points = geopandas.GeoDataFrame(points2016, geometry="loc")
        year = 2016
    elif frame_num == 9:
        points = geopandas.GeoDataFrame(points2017, geometry="loc")
        year = 2017
    elif frame_num == 10:
        points = geopandas.GeoDataFrame(points2018, geometry="loc")
        year = 2018

    ax.cla() # clears plot area (try removing it!)
    city.plot(color="lightgray", ax=ax)
    lakes.plot(color="darkgray", ax=ax)
    points.plot(color="black", marker="x", markersize=200, ax=ax)
    ax.set_axis_off()
    
    ax.text(-89.384054, 43.0, year)
    

HTML(animation.FuncAnimation(fig, update_func, frames=10, interval=1000).to_html5_video())
# Out:
# <video width="864" height="720" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
# With weapon types

# %%
points2018gun = pd.DataFrame(columns=['loc'])
points2018knife = pd.DataFrame(columns=['loc'])

weap2018 = pd.read_csv("NewWeaponVio2018.csv")

xVals = list(weap2018["Longitude"])
yVals = list(weap2018["Latitude"])
types = list(weap2018["WeapType"])
iforgun = 0
iforknife = 0
i = 0

for xVal, yVal, typeof in zip(xVals, yVals, types):

    if typeof == "gun":
        points2018gun.loc[iforgun] = {"loc": Point(xVals[i], yVals[i])}
        iforgun += 1

    if typeof == "knife":
        points2018knife.loc[iforknife] = {"loc": Point(xVals[i], yVals[i])}
        iforknife += 1

    i += 1
    
    
points2017gun = pd.DataFrame(columns=['loc'])
points2017knife = pd.DataFrame(columns=['loc'])

weap2017 = pd.read_csv("NewWeaponVio2017.csv")

xVals = list(weap2017["Longitude"])
yVals = list(weap2017["Latitude"])
types = list(weap2017["WeapType"])
iforgun = 0
iforknife = 0
i = 0

for xVal, yVal, typeof in zip(xVals, yVals, types):

    if typeof == "gun":
        points2017gun.loc[iforgun] = {"loc": Point(xVals[i], yVals[i])}
        iforgun += 1

    if typeof == "knife":
        points2017knife.loc[iforknife] = {"loc": Point(xVals[i], yVals[i])}
        iforknife += 1

    i += 1
    
    
points2016gun = pd.DataFrame(columns=['loc'])
points2016knife = pd.DataFrame(columns=['loc'])

weap2016 = pd.read_csv("NewWeaponVio2016.csv")

xVals = list(weap2016["Longitude"])
yVals = list(weap2016["Latitude"])
types = list(weap2016["WeapType"])
iforgun = 0
iforknife = 0
i = 0

for xVal, yVal, typeof in zip(xVals, yVals, types):

    if typeof == "gun":
        points2016gun.loc[iforgun] = {"loc": Point(xVals[i], yVals[i])}
        iforgun += 1

    if typeof == "knife":
        points2016knife.loc[iforknife] = {"loc": Point(xVals[i], yVals[i])}
        iforknife += 1

    i += 1
    
    
points2015gun = pd.DataFrame(columns=['loc'])
points2015knife = pd.DataFrame(columns=['loc'])

weap2015 = pd.read_csv("NewWeaponVio2015.csv")

xVals = list(weap2015["Longitude"])
yVals = list(weap2015["Latitude"])
types = list(weap2015["WeapType"])
iforgun = 0
iforknife = 0
i = 0

for xVal, yVal, typeof in zip(xVals, yVals, types):

    if typeof == "gun":
        points2015gun.loc[iforgun] = {"loc": Point(xVals[i], yVals[i])}
        iforgun += 1

    if typeof == "knife":
        points2015knife.loc[iforknife] = {"loc": Point(xVals[i], yVals[i])}
        iforknife += 1

    i += 1
    
    
points2014gun = pd.DataFrame(columns=['loc'])
points2014knife = pd.DataFrame(columns=['loc'])

weap2014 = pd.read_csv("NewWeaponVio2014.csv")

xVals = list(weap2014["Longitude"])
yVals = list(weap2014["Latitude"])
types = list(weap2014["WeapType"])
iforgun = 0
iforknife = 0
i = 0

for xVal, yVal, typeof in zip(xVals, yVals, types):

    if typeof == "gun":
        points2014gun.loc[iforgun] = {"loc": Point(xVals[i], yVals[i])}
        iforgun += 1

    if typeof == "knife":
        points2014knife.loc[iforknife] = {"loc": Point(xVals[i], yVals[i])}
        iforknife += 1

    i += 1
    
    
points2013gun = pd.DataFrame(columns=['loc'])
points2013knife = pd.DataFrame(columns=['loc'])

weap2013 = pd.read_csv("NewWeaponVio2013.csv")

xVals = list(weap2013["Longitude"])
yVals = list(weap2013["Latitude"])
types = list(weap2013["WeapType"])
iforgun = 0
iforknife = 0
i = 0

for xVal, yVal, typeof in zip(xVals, yVals, types):

    if typeof == "gun":
        points2013gun.loc[iforgun] = {"loc": Point(xVals[i], yVals[i])}
        iforgun += 1

    if typeof == "knife":
        points2013knife.loc[iforknife] = {"loc": Point(xVals[i], yVals[i])}
        iforknife += 1

    i += 1
    
    
points2012gun = pd.DataFrame(columns=['loc'])
points2012knife = pd.DataFrame(columns=['loc'])

weap2012 = pd.read_csv("NewWeaponVio2012.csv")

xVals = list(weap2012["Longitude"])
yVals = list(weap2012["Latitude"])
types = list(weap2012["WeapType"])
iforgun = 0
iforknife = 0
i = 0

for xVal, yVal, typeof in zip(xVals, yVals, types):

    if typeof == "gun":
        points2012gun.loc[iforgun] = {"loc": Point(xVals[i], yVals[i])}
        iforgun += 1

    if typeof == "knife":
        points2012knife.loc[iforknife] = {"loc": Point(xVals[i], yVals[i])}
        iforknife += 1

    i += 1
    
    
points2011gun = pd.DataFrame(columns=['loc'])
points2011knife = pd.DataFrame(columns=['loc'])

weap2011 = pd.read_csv("NewWeaponVio2011.csv")

xVals = list(weap2011["Longitude"])
yVals = list(weap2011["Latitude"])
types = list(weap2011["WeapType"])
iforgun = 0
iforknife = 0
i = 0

for xVal, yVal, typeof in zip(xVals, yVals, types):

    if typeof == "gun":
        points2011gun.loc[iforgun] = {"loc": Point(xVals[i], yVals[i])}
        iforgun += 1

    if typeof == "knife":
        points2011knife.loc[iforknife] = {"loc": Point(xVals[i], yVals[i])}
        iforknife += 1

    i += 1
    
    
points2010gun = pd.DataFrame(columns=['loc'])
points2010knife = pd.DataFrame(columns=['loc'])

weap2010 = pd.read_csv("NewWeaponVio2010.csv")

xVals = list(weap2010["Longitude"])
yVals = list(weap2010["Latitude"])
types = list(weap2010["WeapType"])
iforgun = 0
iforknife = 0
i = 0

for xVal, yVal, typeof in zip(xVals, yVals, types):

    if typeof == "gun":
        points2010gun.loc[iforgun] = {"loc": Point(xVals[i], yVals[i])}
        iforgun += 1

    if typeof == "knife":
        points2010knife.loc[iforknife] = {"loc": Point(xVals[i], yVals[i])}
        iforknife += 1

    i += 1
    
    
points2009gun = pd.DataFrame(columns=['loc'])
points2009knife = pd.DataFrame(columns=['loc'])

weap2009 = pd.read_csv("NewWeaponVio2009.csv")

xVals = list(weap2009["Longitude"])
yVals = list(weap2009["Latitude"])
types = list(weap2009["WeapType"])
iforgun = 0
iforknife = 0
i = 0

for xVal, yVal, typeof in zip(xVals, yVals, types):

    if typeof == "gun":
        points2009gun.loc[iforgun] = {"loc": Point(xVals[i], yVals[i])}
        iforgun += 1

    if typeof == "knife":
        points2009knife.loc[iforknife] = {"loc": Point(xVals[i], yVals[i])}
        iforknife += 1

    i += 1
    
    
points2008gun = pd.DataFrame(columns=['loc'])
points2008knife = pd.DataFrame(columns=['loc'])

weap2008 = pd.read_csv("NewWeaponVio2008.csv")

xVals = list(weap2008["Longitude"])
yVals = list(weap2008["Latitude"])
types = list(weap2008["WeapType"])
iforgun = 0
iforknife = 0
i = 0

for xVal, yVal, typeof in zip(xVals, yVals, types):

    if typeof == "gun":
        points2008gun.loc[iforgun] = {"loc": Point(xVals[i], yVals[i])}
        iforgun += 1

    if typeof == "knife":
        points2008knife.loc[iforknife] = {"loc": Point(xVals[i], yVals[i])}
        iforknife += 1

    i += 1

# %%
# my version

city = geopandas.read_file("city")
lakes = geopandas.read_file("lakes")



def update_func(frame_num):
    
    if frame_num == 0:
        gunpoints = geopandas.GeoDataFrame(points2008gun, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2008knife, geometry="loc")
        year = 2008
    elif frame_num == 1:
        gunpoints = geopandas.GeoDataFrame(points2009gun, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2009knife, geometry="loc")
        year = 2009
    elif frame_num == 2:
        gunpoints = geopandas.GeoDataFrame(points2010gun, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2010knife, geometry="loc")
        year = 2010
    elif frame_num == 3:
        gunpoints = geopandas.GeoDataFrame(points2011gun, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2011knife, geometry="loc")
        year = 2011
    elif frame_num == 4:
        gunpoints = geopandas.GeoDataFrame(points2012gun, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2012knife, geometry="loc")
        year = 2012
    elif frame_num == 5:
        gunpoints = geopandas.GeoDataFrame(points2013gun, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2013knife, geometry="loc")
        year = 2013
    elif frame_num == 6:
        gunpoints = geopandas.GeoDataFrame(points2014gun, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2014knife, geometry="loc")
        year = 2014
    elif frame_num == 7:
        gunpoints = geopandas.GeoDataFrame(points2015gun, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2015knife, geometry="loc")
        year = 2015
    elif frame_num == 8:
        gunpoints = geopandas.GeoDataFrame(points2016gun, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2016knife, geometry="loc")
        year = 2016
    elif frame_num == 9:
        gunpoints = geopandas.GeoDataFrame(points2017gun, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2017knife, geometry="loc")
        year = 2017
    elif frame_num == 10:
        gunpoints = geopandas.GeoDataFrame(points2018gun, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2018knife, geometry="loc")
        year = 2018

    ax.cla() # clears plot area (try removing it!)
    city.plot(color="lightgray", ax=ax)
    lakes.plot(color="darkgray", ax=ax)
    gunpoints.plot(color="red", marker="x", ax=ax)
    knifepoints.plot(color="blue", marker="x", ax=ax)
    ax.set_axis_off()
    
    ax.text(-89.384054, 43.015, year)
    ax.text(-89.384054, 43.008, "Blue for knife")
    ax.text(-89.384054, 43.001, "Red for gun")
    

with open("out.html", "w") as f:
    f.write(animation.FuncAnimation(fig, update_func, frames=10, interval=2000).to_html5_video())

# %%
# !open out.html

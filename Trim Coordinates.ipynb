# %%
import pandas

# %%
inc2011 = pandas.read_csv("WeaponVio2011.csv")
inc2011
# Out:
#                                                Address  \
# 0                              3700 block Speedway Rd.
# 1                            3000 Block of Darbo Drive
# 2                                       1129 S Park St
# 3                              5700 block Russett Road
# 4                       Verona Road near Midvale Blvd.
# 5                                    4400 Doe Crossing
# 6                    3030 Darbo Drive (Salvation Army)
# 7                                       N. Park Street
# 8                                1800 block Helene Pky
# 9                                 500 block Oak Street
# 10                                     2201 S. Park St
# 11                    311 East Campus Mall (Walgreens)
# 12                               400 block N. Lake St.
# 13                                     1821 S. Park St
# 14                                        Brule Street
# 15                                 1300 blk. Debra La,
# ...

# %%
for i, row in inc2011.iterrows():
    if row["Latitude"] < 43:
        print(i)
#         row["Latitude"] = 43.072160
#         row["Longitude"] = -89.401629
# Out:
# 39
# 55

# %%
inc2011.loc[39, "Latitude"] = 43.072160
inc2011.loc[39, "Longitude"] = -89.401629

inc2011.loc[55, "Latitude"] = 43.072160
inc2011.loc[55, "Longitude"] = -89.401629

# %%
inc2011.to_csv("WeaponVio2011.csv", encoding = 'utf-8', index = False)

# %%
inc2012 = pandas.read_csv("WeaponVio2012.csv")
inc2012
# Out:
#                                                Address  \
# 0                                      117 State St  -
# 1                           2900 Blk of Maple Grove Dr
# 2                       5300 Blk of High Crossing Blvd
# 3                                800 E. Mifflin Street
# 4                                800 Williamson Street
# 5               433 S. Gammon Rd. (Denny's restaurant)
# 6    700 block S. Gammon Road (parking lot outside ...
# 7            701 E. Washington Ave. (High Noon Saloon)
# 8    322 W. Johnson St. (Logan's Madtown restaurant...
# 9                                         McDivitt Rd.
# 10              633 S. Gammon Rd. (Wendy's restaurant)
# 11                              7100 block Flower Lane
# 12                              500 block Moorland Rd.
# 13                                3300 block Wells Ave
# 14                                       Schroeder Rd.
# 15                                     N. Thompson Dr.
# ...

# %%
for i, row in inc2012.iterrows():
    if row["Latitude"] < 43:
        print(i)
#         print(row["Latitude"])
#         print(row["Longitude"])
#         row["Latitude"] = 43.072160
#         row["Longitude"] = -89.401629
# Out:
# 48

# %%
inc2012.loc[48, "Latitude"] = 43.072160
inc2012.loc[48, "Longitude"] = -89.401629

# %%
inc2012.to_csv("WeaponVio2012.csv", encoding = 'utf-8', index = False)

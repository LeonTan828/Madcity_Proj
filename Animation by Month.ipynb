# %%
# %matplotlib inline

# %%
import pandas as pd
import geopandas # we'll use this to read shapefiles
from shapely.geometry import Polygon, Point
from matplotlib import pyplot as plt
from matplotlib import animation
from IPython.display import HTML

# %%
# %%capture
fig, ax = plt.subplots(figsize = (12,10))

# %%
points2018gunJan = pd.DataFrame(columns=['loc'])
points2018gunFeb = pd.DataFrame(columns=['loc'])
points2018gunMar = pd.DataFrame(columns=['loc'])
points2018gunApr = pd.DataFrame(columns=['loc'])
points2018gunMay = pd.DataFrame(columns=['loc'])
points2018gunJun = pd.DataFrame(columns=['loc'])
points2018gunJul = pd.DataFrame(columns=['loc'])
points2018gunAug = pd.DataFrame(columns=['loc'])
points2018gunSep = pd.DataFrame(columns=['loc'])
points2018gunOct = pd.DataFrame(columns=['loc'])
points2018gunNov = pd.DataFrame(columns=['loc'])
points2018gunDec = pd.DataFrame(columns=['loc'])

points2018knifeJan = pd.DataFrame(columns=['loc'])
points2018knifeFeb = pd.DataFrame(columns=['loc'])
points2018knifeMar = pd.DataFrame(columns=['loc'])
points2018knifeApr = pd.DataFrame(columns=['loc'])
points2018knifeMay = pd.DataFrame(columns=['loc'])
points2018knifeJun = pd.DataFrame(columns=['loc'])
points2018knifeJul = pd.DataFrame(columns=['loc'])
points2018knifeAug = pd.DataFrame(columns=['loc'])
points2018knifeSep = pd.DataFrame(columns=['loc'])
points2018knifeOct = pd.DataFrame(columns=['loc'])
points2018knifeNov = pd.DataFrame(columns=['loc'])
points2018knifeDec = pd.DataFrame(columns=['loc'])

weap2018 = pd.read_csv("NewWeaponVio2018.csv")

xVals = list(weap2018["Longitude"])
yVals = list(weap2018["Latitude"])
types = list(weap2018["WeapType"])
months = list(weap2018["Month"])
i = 0

for xVal, yVal, typeof, month in zip(xVals, yVals, types, months):

    if typeof == "gun":
        if month == "Jan":
            points2018gunJan.loc[len(points2018gunJan)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Feb":
            points2018gunFeb.loc[len(points2018gunFeb)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Mar":
            points2018gunMar.loc[len(points2018gunMar)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Apr":
            points2018gunApr.loc[len(points2018gunApr)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "May":
            points2018gunMay.loc[len(points2018gunMay)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Jun":
            points2018gunJun.loc[len(points2018gunJun)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Jul":
            points2018gunJul.loc[len(points2018gunJul)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Aug":
            points2018gunAug.loc[len(points2018gunAug)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Sep":
            points2018gunSep.loc[len(points2018gunSep)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Oct":
            points2018gunOct.loc[len(points2018gunOct)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Nov":
            points2018gunNov.loc[len(points2018gunNov)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Dec":
            points2018gunDec.loc[len(points2018gunDec)] = {"loc": Point(xVals[i], yVals[i])}
        


    if typeof == "knife":
        if month == "Jan":
            points2018knifeJan.loc[len(points2018knifeJan)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Feb":
            points2018knifeFeb.loc[len(points2018knifeFeb)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Mar":
            points2018knifeMar.loc[len(points2018knifeMar)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Apr":
            points2018knifeApr.loc[len(points2018knifeApr)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "May":
            points2018knifeMay.loc[len(points2018knifeMay)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Jun":
            points2018knifeJun.loc[len(points2018knifeJun)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Jul":
            points2018knifeJul.loc[len(points2018knifeJul)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Aug":
            points2018knifeAug.loc[len(points2018knifeAug)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Sep":
            points2018knifeSep.loc[len(points2018knifeSep)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Oct":
            points2018knifeOct.loc[len(points2018knifeOct)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Nov":
            points2018knifeNov.loc[len(points2018knifeNov)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Dec":
            points2018knifeDec.loc[len(points2018knifeDec)] = {"loc": Point(xVals[i], yVals[i])}

    i += 1


points2017gunJan = pd.DataFrame(columns=['loc'])
points2017gunFeb = pd.DataFrame(columns=['loc'])
points2017gunMar = pd.DataFrame(columns=['loc'])
points2017gunApr = pd.DataFrame(columns=['loc'])
points2017gunMay = pd.DataFrame(columns=['loc'])
points2017gunJun = pd.DataFrame(columns=['loc'])
points2017gunJul = pd.DataFrame(columns=['loc'])
points2017gunAug = pd.DataFrame(columns=['loc'])
points2017gunSep = pd.DataFrame(columns=['loc'])
points2017gunOct = pd.DataFrame(columns=['loc'])
points2017gunNov = pd.DataFrame(columns=['loc'])
points2017gunDec = pd.DataFrame(columns=['loc'])

points2017knifeJan = pd.DataFrame(columns=['loc'])
points2017knifeFeb = pd.DataFrame(columns=['loc'])
points2017knifeMar = pd.DataFrame(columns=['loc'])
points2017knifeApr = pd.DataFrame(columns=['loc'])
points2017knifeMay = pd.DataFrame(columns=['loc'])
points2017knifeJun = pd.DataFrame(columns=['loc'])
points2017knifeJul = pd.DataFrame(columns=['loc'])
points2017knifeAug = pd.DataFrame(columns=['loc'])
points2017knifeSep = pd.DataFrame(columns=['loc'])
points2017knifeOct = pd.DataFrame(columns=['loc'])
points2017knifeNov = pd.DataFrame(columns=['loc'])
points2017knifeDec = pd.DataFrame(columns=['loc'])

weap2017 = pd.read_csv("NewWeaponVio2017.csv")

xVals = list(weap2017["Longitude"])
yVals = list(weap2017["Latitude"])
types = list(weap2017["WeapType"])
months = list(weap2017["Month"])
i = 0

for xVal, yVal, typeof, month in zip(xVals, yVals, types, months):

    if typeof == "gun":
        if month == "Jan":
            points2017gunJan.loc[len(points2017gunJan)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Feb":
            points2017gunFeb.loc[len(points2017gunFeb)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Mar":
            points2017gunMar.loc[len(points2017gunMar)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Apr":
            points2017gunApr.loc[len(points2017gunApr)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "May":
            points2017gunMay.loc[len(points2017gunMay)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Jun":
            points2017gunJun.loc[len(points2017gunJun)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Jul":
            points2017gunJul.loc[len(points2017gunJul)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Aug":
            points2017gunAug.loc[len(points2017gunAug)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Sep":
            points2017gunSep.loc[len(points2017gunSep)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Oct":
            points2017gunOct.loc[len(points2017gunOct)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Nov":
            points2017gunNov.loc[len(points2017gunNov)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Dec":
            points2017gunDec.loc[len(points2017gunDec)] = {"loc": Point(xVals[i], yVals[i])}
        


    if typeof == "knife":
        if month == "Jan":
            points2017knifeJan.loc[len(points2017knifeJan)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Feb":
            points2017knifeFeb.loc[len(points2017knifeFeb)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Mar":
            points2017knifeMar.loc[len(points2017knifeMar)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Apr":
            points2017knifeApr.loc[len(points2017knifeApr)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "May":
            points2017knifeMay.loc[len(points2017knifeMay)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Jun":
            points2017knifeJun.loc[len(points2017knifeJun)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Jul":
            points2017knifeJul.loc[len(points2017knifeJul)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Aug":
            points2017knifeAug.loc[len(points2017knifeAug)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Sep":
            points2017knifeSep.loc[len(points2017knifeSep)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Oct":
            points2017knifeOct.loc[len(points2017knifeOct)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Nov":
            points2017knifeNov.loc[len(points2017knifeNov)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Dec":
            points2017knifeDec.loc[len(points2017knifeDec)] = {"loc": Point(xVals[i], yVals[i])}

    i += 1



points2016gunJan = pd.DataFrame(columns=['loc'])
points2016gunFeb = pd.DataFrame(columns=['loc'])
points2016gunMar = pd.DataFrame(columns=['loc'])
points2016gunApr = pd.DataFrame(columns=['loc'])
points2016gunMay = pd.DataFrame(columns=['loc'])
points2016gunJun = pd.DataFrame(columns=['loc'])
points2016gunJul = pd.DataFrame(columns=['loc'])
points2016gunAug = pd.DataFrame(columns=['loc'])
points2016gunSep = pd.DataFrame(columns=['loc'])
points2016gunOct = pd.DataFrame(columns=['loc'])
points2016gunNov = pd.DataFrame(columns=['loc'])
points2016gunDec = pd.DataFrame(columns=['loc'])

points2016knifeJan = pd.DataFrame(columns=['loc'])
points2016knifeFeb = pd.DataFrame(columns=['loc'])
points2016knifeMar = pd.DataFrame(columns=['loc'])
points2016knifeApr = pd.DataFrame(columns=['loc'])
points2016knifeMay = pd.DataFrame(columns=['loc'])
points2016knifeJun = pd.DataFrame(columns=['loc'])
points2016knifeJul = pd.DataFrame(columns=['loc'])
points2016knifeAug = pd.DataFrame(columns=['loc'])
points2016knifeSep = pd.DataFrame(columns=['loc'])
points2016knifeOct = pd.DataFrame(columns=['loc'])
points2016knifeNov = pd.DataFrame(columns=['loc'])
points2016knifeDec = pd.DataFrame(columns=['loc'])

weap2016 = pd.read_csv("NewWeaponVio2016.csv")

xVals = list(weap2016["Longitude"])
yVals = list(weap2016["Latitude"])
types = list(weap2016["WeapType"])
months = list(weap2016["Month"])
i = 0

for xVal, yVal, typeof, month in zip(xVals, yVals, types, months):

    if typeof == "gun":
        if month == "Jan":
            points2016gunJan.loc[len(points2016gunJan)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Feb":
            points2016gunFeb.loc[len(points2016gunFeb)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Mar":
            points2016gunMar.loc[len(points2016gunMar)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Apr":
            points2016gunApr.loc[len(points2016gunApr)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "May":
            points2016gunMay.loc[len(points2016gunMay)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Jun":
            points2016gunJun.loc[len(points2016gunJun)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Jul":
            points2016gunJul.loc[len(points2016gunJul)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Aug":
            points2016gunAug.loc[len(points2016gunAug)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Sep":
            points2016gunSep.loc[len(points2016gunSep)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Oct":
            points2016gunOct.loc[len(points2016gunOct)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Nov":
            points2016gunNov.loc[len(points2016gunNov)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Dec":
            points2016gunDec.loc[len(points2016gunDec)] = {"loc": Point(xVals[i], yVals[i])}
        


    if typeof == "knife":
        if month == "Jan":
            points2016knifeJan.loc[len(points2016knifeJan)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Feb":
            points2016knifeFeb.loc[len(points2016knifeFeb)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Mar":
            points2016knifeMar.loc[len(points2016knifeMar)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Apr":
            points2016knifeApr.loc[len(points2016knifeApr)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "May":
            points2016knifeMay.loc[len(points2016knifeMay)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Jun":
            points2016knifeJun.loc[len(points2016knifeJun)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Jul":
            points2016knifeJul.loc[len(points2016knifeJul)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Aug":
            points2016knifeAug.loc[len(points2016knifeAug)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Sep":
            points2016knifeSep.loc[len(points2016knifeSep)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Oct":
            points2016knifeOct.loc[len(points2016knifeOct)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Nov":
            points2016knifeNov.loc[len(points2016knifeNov)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Dec":
            points2016knifeDec.loc[len(points2016knifeDec)] = {"loc": Point(xVals[i], yVals[i])}

    i += 1



points2015gunJan = pd.DataFrame(columns=['loc'])
points2015gunFeb = pd.DataFrame(columns=['loc'])
points2015gunMar = pd.DataFrame(columns=['loc'])
points2015gunApr = pd.DataFrame(columns=['loc'])
points2015gunMay = pd.DataFrame(columns=['loc'])
points2015gunJun = pd.DataFrame(columns=['loc'])
points2015gunJul = pd.DataFrame(columns=['loc'])
points2015gunAug = pd.DataFrame(columns=['loc'])
points2015gunSep = pd.DataFrame(columns=['loc'])
points2015gunOct = pd.DataFrame(columns=['loc'])
points2015gunNov = pd.DataFrame(columns=['loc'])
points2015gunDec = pd.DataFrame(columns=['loc'])

points2015knifeJan = pd.DataFrame(columns=['loc'])
points2015knifeFeb = pd.DataFrame(columns=['loc'])
points2015knifeMar = pd.DataFrame(columns=['loc'])
points2015knifeApr = pd.DataFrame(columns=['loc'])
points2015knifeMay = pd.DataFrame(columns=['loc'])
points2015knifeJun = pd.DataFrame(columns=['loc'])
points2015knifeJul = pd.DataFrame(columns=['loc'])
points2015knifeAug = pd.DataFrame(columns=['loc'])
points2015knifeSep = pd.DataFrame(columns=['loc'])
points2015knifeOct = pd.DataFrame(columns=['loc'])
points2015knifeNov = pd.DataFrame(columns=['loc'])
points2015knifeDec = pd.DataFrame(columns=['loc'])

weap2015 = pd.read_csv("NewWeaponVio2015.csv")

xVals = list(weap2015["Longitude"])
yVals = list(weap2015["Latitude"])
types = list(weap2015["WeapType"])
months = list(weap2015["Month"])
i = 0

for xVal, yVal, typeof, month in zip(xVals, yVals, types, months):

    if typeof == "gun":
        if month == "Jan":
            points2015gunJan.loc[len(points2015gunJan)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Feb":
            points2015gunFeb.loc[len(points2015gunFeb)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Mar":
            points2015gunMar.loc[len(points2015gunMar)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Apr":
            points2015gunApr.loc[len(points2015gunApr)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "May":
            points2015gunMay.loc[len(points2015gunMay)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Jun":
            points2015gunJun.loc[len(points2015gunJun)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Jul":
            points2015gunJul.loc[len(points2015gunJul)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Aug":
            points2015gunAug.loc[len(points2015gunAug)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Sep":
            points2015gunSep.loc[len(points2015gunSep)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Oct":
            points2015gunOct.loc[len(points2015gunOct)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Nov":
            points2015gunNov.loc[len(points2015gunNov)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Dec":
            points2015gunDec.loc[len(points2015gunDec)] = {"loc": Point(xVals[i], yVals[i])}
        


    if typeof == "knife":
        if month == "Jan":
            points2015knifeJan.loc[len(points2015knifeJan)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Feb":
            points2015knifeFeb.loc[len(points2015knifeFeb)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Mar":
            points2015knifeMar.loc[len(points2015knifeMar)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Apr":
            points2015knifeApr.loc[len(points2015knifeApr)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "May":
            points2015knifeMay.loc[len(points2015knifeMay)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Jun":
            points2015knifeJun.loc[len(points2015knifeJun)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Jul":
            points2015knifeJul.loc[len(points2015knifeJul)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Aug":
            points2015knifeAug.loc[len(points2015knifeAug)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Sep":
            points2015knifeSep.loc[len(points2015knifeSep)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Oct":
            points2015knifeOct.loc[len(points2015knifeOct)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Nov":
            points2015knifeNov.loc[len(points2015knifeNov)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Dec":
            points2015knifeDec.loc[len(points2015knifeDec)] = {"loc": Point(xVals[i], yVals[i])}

    i += 1



points2014gunJan = pd.DataFrame(columns=['loc'])
points2014gunFeb = pd.DataFrame(columns=['loc'])
points2014gunMar = pd.DataFrame(columns=['loc'])
points2014gunApr = pd.DataFrame(columns=['loc'])
points2014gunMay = pd.DataFrame(columns=['loc'])
points2014gunJun = pd.DataFrame(columns=['loc'])
points2014gunJul = pd.DataFrame(columns=['loc'])
points2014gunAug = pd.DataFrame(columns=['loc'])
points2014gunSep = pd.DataFrame(columns=['loc'])
points2014gunOct = pd.DataFrame(columns=['loc'])
points2014gunNov = pd.DataFrame(columns=['loc'])
points2014gunDec = pd.DataFrame(columns=['loc'])

points2014knifeJan = pd.DataFrame(columns=['loc'])
points2014knifeFeb = pd.DataFrame(columns=['loc'])
points2014knifeMar = pd.DataFrame(columns=['loc'])
points2014knifeApr = pd.DataFrame(columns=['loc'])
points2014knifeMay = pd.DataFrame(columns=['loc'])
points2014knifeJun = pd.DataFrame(columns=['loc'])
points2014knifeJul = pd.DataFrame(columns=['loc'])
points2014knifeAug = pd.DataFrame(columns=['loc'])
points2014knifeSep = pd.DataFrame(columns=['loc'])
points2014knifeOct = pd.DataFrame(columns=['loc'])
points2014knifeNov = pd.DataFrame(columns=['loc'])
points2014knifeDec = pd.DataFrame(columns=['loc'])

weap2014 = pd.read_csv("NewWeaponVio2014.csv")

xVals = list(weap2014["Longitude"])
yVals = list(weap2014["Latitude"])
types = list(weap2014["WeapType"])
months = list(weap2014["Month"])
i = 0

for xVal, yVal, typeof, month in zip(xVals, yVals, types, months):

    if typeof == "gun":
        if month == "Jan":
            points2014gunJan.loc[len(points2014gunJan)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Feb":
            points2014gunFeb.loc[len(points2014gunFeb)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Mar":
            points2014gunMar.loc[len(points2014gunMar)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Apr":
            points2014gunApr.loc[len(points2014gunApr)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "May":
            points2014gunMay.loc[len(points2014gunMay)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Jun":
            points2014gunJun.loc[len(points2014gunJun)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Jul":
            points2014gunJul.loc[len(points2014gunJul)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Aug":
            points2014gunAug.loc[len(points2014gunAug)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Sep":
            points2014gunSep.loc[len(points2014gunSep)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Oct":
            points2014gunOct.loc[len(points2014gunOct)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Nov":
            points2014gunNov.loc[len(points2014gunNov)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Dec":
            points2014gunDec.loc[len(points2014gunDec)] = {"loc": Point(xVals[i], yVals[i])}
        


    if typeof == "knife":
        if month == "Jan":
            points2014knifeJan.loc[len(points2014knifeJan)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Feb":
            points2014knifeFeb.loc[len(points2014knifeFeb)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Mar":
            points2014knifeMar.loc[len(points2014knifeMar)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Apr":
            points2014knifeApr.loc[len(points2014knifeApr)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "May":
            points2014knifeMay.loc[len(points2014knifeMay)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Jun":
            points2014knifeJun.loc[len(points2014knifeJun)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Jul":
            points2014knifeJul.loc[len(points2014knifeJul)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Aug":
            points2014knifeAug.loc[len(points2014knifeAug)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Sep":
            points2014knifeSep.loc[len(points2014knifeSep)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Oct":
            points2014knifeOct.loc[len(points2014knifeOct)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Nov":
            points2014knifeNov.loc[len(points2014knifeNov)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Dec":
            points2014knifeDec.loc[len(points2014knifeDec)] = {"loc": Point(xVals[i], yVals[i])}

    i += 1



points2013gunJan = pd.DataFrame(columns=['loc'])
points2013gunFeb = pd.DataFrame(columns=['loc'])
points2013gunMar = pd.DataFrame(columns=['loc'])
points2013gunApr = pd.DataFrame(columns=['loc'])
points2013gunMay = pd.DataFrame(columns=['loc'])
points2013gunJun = pd.DataFrame(columns=['loc'])
points2013gunJul = pd.DataFrame(columns=['loc'])
points2013gunAug = pd.DataFrame(columns=['loc'])
points2013gunSep = pd.DataFrame(columns=['loc'])
points2013gunOct = pd.DataFrame(columns=['loc'])
points2013gunNov = pd.DataFrame(columns=['loc'])
points2013gunDec = pd.DataFrame(columns=['loc'])

points2013knifeJan = pd.DataFrame(columns=['loc'])
points2013knifeFeb = pd.DataFrame(columns=['loc'])
points2013knifeMar = pd.DataFrame(columns=['loc'])
points2013knifeApr = pd.DataFrame(columns=['loc'])
points2013knifeMay = pd.DataFrame(columns=['loc'])
points2013knifeJun = pd.DataFrame(columns=['loc'])
points2013knifeJul = pd.DataFrame(columns=['loc'])
points2013knifeAug = pd.DataFrame(columns=['loc'])
points2013knifeSep = pd.DataFrame(columns=['loc'])
points2013knifeOct = pd.DataFrame(columns=['loc'])
points2013knifeNov = pd.DataFrame(columns=['loc'])
points2013knifeDec = pd.DataFrame(columns=['loc'])

weap2013 = pd.read_csv("NewWeaponVio2013.csv")

xVals = list(weap2013["Longitude"])
yVals = list(weap2013["Latitude"])
types = list(weap2013["WeapType"])
months = list(weap2013["Month"])
i = 0

for xVal, yVal, typeof, month in zip(xVals, yVals, types, months):

    if typeof == "gun":
        if month == "Jan":
            points2013gunJan.loc[len(points2013gunJan)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Feb":
            points2013gunFeb.loc[len(points2013gunFeb)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Mar":
            points2013gunMar.loc[len(points2013gunMar)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Apr":
            points2013gunApr.loc[len(points2013gunApr)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "May":
            points2013gunMay.loc[len(points2013gunMay)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Jun":
            points2013gunJun.loc[len(points2013gunJun)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Jul":
            points2013gunJul.loc[len(points2013gunJul)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Aug":
            points2013gunAug.loc[len(points2013gunAug)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Sep":
            points2013gunSep.loc[len(points2013gunSep)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Oct":
            points2013gunOct.loc[len(points2013gunOct)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Nov":
            points2013gunNov.loc[len(points2013gunNov)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Dec":
            points2013gunDec.loc[len(points2013gunDec)] = {"loc": Point(xVals[i], yVals[i])}
        


    if typeof == "knife":
        if month == "Jan":
            points2013knifeJan.loc[len(points2013knifeJan)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Feb":
            points2013knifeFeb.loc[len(points2013knifeFeb)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Mar":
            points2013knifeMar.loc[len(points2013knifeMar)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Apr":
            points2013knifeApr.loc[len(points2013knifeApr)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "May":
            points2013knifeMay.loc[len(points2013knifeMay)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Jun":
            points2013knifeJun.loc[len(points2013knifeJun)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Jul":
            points2013knifeJul.loc[len(points2013knifeJul)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Aug":
            points2013knifeAug.loc[len(points2013knifeAug)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Sep":
            points2013knifeSep.loc[len(points2013knifeSep)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Oct":
            points2013knifeOct.loc[len(points2013knifeOct)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Nov":
            points2013knifeNov.loc[len(points2013knifeNov)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Dec":
            points2013knifeDec.loc[len(points2013knifeDec)] = {"loc": Point(xVals[i], yVals[i])}

    i += 1



points2012gunJan = pd.DataFrame(columns=['loc'])
points2012gunFeb = pd.DataFrame(columns=['loc'])
points2012gunMar = pd.DataFrame(columns=['loc'])
points2012gunApr = pd.DataFrame(columns=['loc'])
points2012gunMay = pd.DataFrame(columns=['loc'])
points2012gunJun = pd.DataFrame(columns=['loc'])
points2012gunJul = pd.DataFrame(columns=['loc'])
points2012gunAug = pd.DataFrame(columns=['loc'])
points2012gunSep = pd.DataFrame(columns=['loc'])
points2012gunOct = pd.DataFrame(columns=['loc'])
points2012gunNov = pd.DataFrame(columns=['loc'])
points2012gunDec = pd.DataFrame(columns=['loc'])

points2012knifeJan = pd.DataFrame(columns=['loc'])
points2012knifeFeb = pd.DataFrame(columns=['loc'])
points2012knifeMar = pd.DataFrame(columns=['loc'])
points2012knifeApr = pd.DataFrame(columns=['loc'])
points2012knifeMay = pd.DataFrame(columns=['loc'])
points2012knifeJun = pd.DataFrame(columns=['loc'])
points2012knifeJul = pd.DataFrame(columns=['loc'])
points2012knifeAug = pd.DataFrame(columns=['loc'])
points2012knifeSep = pd.DataFrame(columns=['loc'])
points2012knifeOct = pd.DataFrame(columns=['loc'])
points2012knifeNov = pd.DataFrame(columns=['loc'])
points2012knifeDec = pd.DataFrame(columns=['loc'])

weap2012 = pd.read_csv("NewWeaponVio2012.csv")

xVals = list(weap2012["Longitude"])
yVals = list(weap2012["Latitude"])
types = list(weap2012["WeapType"])
months = list(weap2012["Month"])
i = 0

for xVal, yVal, typeof, month in zip(xVals, yVals, types, months):

    if typeof == "gun":
        if month == "Jan":
            points2012gunJan.loc[len(points2012gunJan)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Feb":
            points2012gunFeb.loc[len(points2012gunFeb)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Mar":
            points2012gunMar.loc[len(points2012gunMar)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Apr":
            points2012gunApr.loc[len(points2012gunApr)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "May":
            points2012gunMay.loc[len(points2012gunMay)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Jun":
            points2012gunJun.loc[len(points2012gunJun)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Jul":
            points2012gunJul.loc[len(points2012gunJul)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Aug":
            points2012gunAug.loc[len(points2012gunAug)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Sep":
            points2012gunSep.loc[len(points2012gunSep)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Oct":
            points2012gunOct.loc[len(points2012gunOct)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Nov":
            points2012gunNov.loc[len(points2012gunNov)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Dec":
            points2012gunDec.loc[len(points2012gunDec)] = {"loc": Point(xVals[i], yVals[i])}
        


    if typeof == "knife":
        if month == "Jan":
            points2012knifeJan.loc[len(points2012knifeJan)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Feb":
            points2012knifeFeb.loc[len(points2012knifeFeb)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Mar":
            points2012knifeMar.loc[len(points2012knifeMar)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Apr":
            points2012knifeApr.loc[len(points2012knifeApr)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "May":
            points2012knifeMay.loc[len(points2012knifeMay)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Jun":
            points2012knifeJun.loc[len(points2012knifeJun)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Jul":
            points2012knifeJul.loc[len(points2012knifeJul)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Aug":
            points2012knifeAug.loc[len(points2012knifeAug)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Sep":
            points2012knifeSep.loc[len(points2012knifeSep)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Oct":
            points2012knifeOct.loc[len(points2012knifeOct)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Nov":
            points2012knifeNov.loc[len(points2012knifeNov)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Dec":
            points2012knifeDec.loc[len(points2012knifeDec)] = {"loc": Point(xVals[i], yVals[i])}

    i += 1



points2011gunJan = pd.DataFrame(columns=['loc'])
points2011gunFeb = pd.DataFrame(columns=['loc'])
points2011gunMar = pd.DataFrame(columns=['loc'])
points2011gunApr = pd.DataFrame(columns=['loc'])
points2011gunMay = pd.DataFrame(columns=['loc'])
points2011gunJun = pd.DataFrame(columns=['loc'])
points2011gunJul = pd.DataFrame(columns=['loc'])
points2011gunAug = pd.DataFrame(columns=['loc'])
points2011gunSep = pd.DataFrame(columns=['loc'])
points2011gunOct = pd.DataFrame(columns=['loc'])
points2011gunNov = pd.DataFrame(columns=['loc'])
points2011gunDec = pd.DataFrame(columns=['loc'])

points2011knifeJan = pd.DataFrame(columns=['loc'])
points2011knifeFeb = pd.DataFrame(columns=['loc'])
points2011knifeMar = pd.DataFrame(columns=['loc'])
points2011knifeApr = pd.DataFrame(columns=['loc'])
points2011knifeMay = pd.DataFrame(columns=['loc'])
points2011knifeJun = pd.DataFrame(columns=['loc'])
points2011knifeJul = pd.DataFrame(columns=['loc'])
points2011knifeAug = pd.DataFrame(columns=['loc'])
points2011knifeSep = pd.DataFrame(columns=['loc'])
points2011knifeOct = pd.DataFrame(columns=['loc'])
points2011knifeNov = pd.DataFrame(columns=['loc'])
points2011knifeDec = pd.DataFrame(columns=['loc'])

weap2011 = pd.read_csv("NewWeaponVio2011.csv")

xVals = list(weap2011["Longitude"])
yVals = list(weap2011["Latitude"])
types = list(weap2011["WeapType"])
months = list(weap2011["Month"])
i = 0

for xVal, yVal, typeof, month in zip(xVals, yVals, types, months):

    if typeof == "gun":
        if month == "Jan":
            points2011gunJan.loc[len(points2011gunJan)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Feb":
            points2011gunFeb.loc[len(points2011gunFeb)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Mar":
            points2011gunMar.loc[len(points2011gunMar)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Apr":
            points2011gunApr.loc[len(points2011gunApr)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "May":
            points2011gunMay.loc[len(points2011gunMay)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Jun":
            points2011gunJun.loc[len(points2011gunJun)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Jul":
            points2011gunJul.loc[len(points2011gunJul)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Aug":
            points2011gunAug.loc[len(points2011gunAug)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Sep":
            points2011gunSep.loc[len(points2011gunSep)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Oct":
            points2011gunOct.loc[len(points2011gunOct)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Nov":
            points2011gunNov.loc[len(points2011gunNov)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Dec":
            points2011gunDec.loc[len(points2011gunDec)] = {"loc": Point(xVals[i], yVals[i])}
        


    if typeof == "knife":
        if month == "Jan":
            points2011knifeJan.loc[len(points2011knifeJan)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Feb":
            points2011knifeFeb.loc[len(points2011knifeFeb)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Mar":
            points2011knifeMar.loc[len(points2011knifeMar)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Apr":
            points2011knifeApr.loc[len(points2011knifeApr)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "May":
            points2011knifeMay.loc[len(points2011knifeMay)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Jun":
            points2011knifeJun.loc[len(points2011knifeJun)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Jul":
            points2011knifeJul.loc[len(points2011knifeJul)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Aug":
            points2011knifeAug.loc[len(points2011knifeAug)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Sep":
            points2011knifeSep.loc[len(points2011knifeSep)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Oct":
            points2011knifeOct.loc[len(points2011knifeOct)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Nov":
            points2011knifeNov.loc[len(points2011knifeNov)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Dec":
            points2011knifeDec.loc[len(points2011knifeDec)] = {"loc": Point(xVals[i], yVals[i])}

    i += 1



points2010gunJan = pd.DataFrame(columns=['loc'])
points2010gunFeb = pd.DataFrame(columns=['loc'])
points2010gunMar = pd.DataFrame(columns=['loc'])
points2010gunApr = pd.DataFrame(columns=['loc'])
points2010gunMay = pd.DataFrame(columns=['loc'])
points2010gunJun = pd.DataFrame(columns=['loc'])
points2010gunJul = pd.DataFrame(columns=['loc'])
points2010gunAug = pd.DataFrame(columns=['loc'])
points2010gunSep = pd.DataFrame(columns=['loc'])
points2010gunOct = pd.DataFrame(columns=['loc'])
points2010gunNov = pd.DataFrame(columns=['loc'])
points2010gunDec = pd.DataFrame(columns=['loc'])

points2010knifeJan = pd.DataFrame(columns=['loc'])
points2010knifeFeb = pd.DataFrame(columns=['loc'])
points2010knifeMar = pd.DataFrame(columns=['loc'])
points2010knifeApr = pd.DataFrame(columns=['loc'])
points2010knifeMay = pd.DataFrame(columns=['loc'])
points2010knifeJun = pd.DataFrame(columns=['loc'])
points2010knifeJul = pd.DataFrame(columns=['loc'])
points2010knifeAug = pd.DataFrame(columns=['loc'])
points2010knifeSep = pd.DataFrame(columns=['loc'])
points2010knifeOct = pd.DataFrame(columns=['loc'])
points2010knifeNov = pd.DataFrame(columns=['loc'])
points2010knifeDec = pd.DataFrame(columns=['loc'])

weap2010 = pd.read_csv("NewWeaponVio2010.csv")

xVals = list(weap2010["Longitude"])
yVals = list(weap2010["Latitude"])
types = list(weap2010["WeapType"])
months = list(weap2010["Month"])
i = 0

for xVal, yVal, typeof, month in zip(xVals, yVals, types, months):

    if typeof == "gun":
        if month == "Jan":
            points2010gunJan.loc[len(points2010gunJan)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Feb":
            points2010gunFeb.loc[len(points2010gunFeb)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Mar":
            points2010gunMar.loc[len(points2010gunMar)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Apr":
            points2010gunApr.loc[len(points2010gunApr)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "May":
            points2010gunMay.loc[len(points2010gunMay)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Jun":
            points2010gunJun.loc[len(points2010gunJun)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Jul":
            points2010gunJul.loc[len(points2010gunJul)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Aug":
            points2010gunAug.loc[len(points2010gunAug)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Sep":
            points2010gunSep.loc[len(points2010gunSep)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Oct":
            points2010gunOct.loc[len(points2010gunOct)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Nov":
            points2010gunNov.loc[len(points2010gunNov)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Dec":
            points2010gunDec.loc[len(points2010gunDec)] = {"loc": Point(xVals[i], yVals[i])}
        


    if typeof == "knife":
        if month == "Jan":
            points2010knifeJan.loc[len(points2010knifeJan)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Feb":
            points2010knifeFeb.loc[len(points2010knifeFeb)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Mar":
            points2010knifeMar.loc[len(points2010knifeMar)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Apr":
            points2010knifeApr.loc[len(points2010knifeApr)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "May":
            points2010knifeMay.loc[len(points2010knifeMay)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Jun":
            points2010knifeJun.loc[len(points2010knifeJun)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Jul":
            points2010knifeJul.loc[len(points2010knifeJul)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Aug":
            points2010knifeAug.loc[len(points2010knifeAug)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Sep":
            points2010knifeSep.loc[len(points2010knifeSep)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Oct":
            points2010knifeOct.loc[len(points2010knifeOct)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Nov":
            points2010knifeNov.loc[len(points2010knifeNov)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Dec":
            points2010knifeDec.loc[len(points2010knifeDec)] = {"loc": Point(xVals[i], yVals[i])}

    i += 1



points2009gunJan = pd.DataFrame(columns=['loc'])
points2009gunFeb = pd.DataFrame(columns=['loc'])
points2009gunMar = pd.DataFrame(columns=['loc'])
points2009gunApr = pd.DataFrame(columns=['loc'])
points2009gunMay = pd.DataFrame(columns=['loc'])
points2009gunJun = pd.DataFrame(columns=['loc'])
points2009gunJul = pd.DataFrame(columns=['loc'])
points2009gunAug = pd.DataFrame(columns=['loc'])
points2009gunSep = pd.DataFrame(columns=['loc'])
points2009gunOct = pd.DataFrame(columns=['loc'])
points2009gunNov = pd.DataFrame(columns=['loc'])
points2009gunDec = pd.DataFrame(columns=['loc'])

points2009knifeJan = pd.DataFrame(columns=['loc'])
points2009knifeFeb = pd.DataFrame(columns=['loc'])
points2009knifeMar = pd.DataFrame(columns=['loc'])
points2009knifeApr = pd.DataFrame(columns=['loc'])
points2009knifeMay = pd.DataFrame(columns=['loc'])
points2009knifeJun = pd.DataFrame(columns=['loc'])
points2009knifeJul = pd.DataFrame(columns=['loc'])
points2009knifeAug = pd.DataFrame(columns=['loc'])
points2009knifeSep = pd.DataFrame(columns=['loc'])
points2009knifeOct = pd.DataFrame(columns=['loc'])
points2009knifeNov = pd.DataFrame(columns=['loc'])
points2009knifeDec = pd.DataFrame(columns=['loc'])

weap2009 = pd.read_csv("NewWeaponVio2009.csv")

xVals = list(weap2009["Longitude"])
yVals = list(weap2009["Latitude"])
types = list(weap2009["WeapType"])
months = list(weap2009["Month"])
i = 0

for xVal, yVal, typeof, month in zip(xVals, yVals, types, months):

    if typeof == "gun":
        if month == "Jan":
            points2009gunJan.loc[len(points2009gunJan)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Feb":
            points2009gunFeb.loc[len(points2009gunFeb)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Mar":
            points2009gunMar.loc[len(points2009gunMar)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Apr":
            points2009gunApr.loc[len(points2009gunApr)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "May":
            points2009gunMay.loc[len(points2009gunMay)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Jun":
            points2009gunJun.loc[len(points2009gunJun)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Jul":
            points2009gunJul.loc[len(points2009gunJul)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Aug":
            points2009gunAug.loc[len(points2009gunAug)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Sep":
            points2009gunSep.loc[len(points2009gunSep)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Oct":
            points2009gunOct.loc[len(points2009gunOct)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Nov":
            points2009gunNov.loc[len(points2009gunNov)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Dec":
            points2009gunDec.loc[len(points2009gunDec)] = {"loc": Point(xVals[i], yVals[i])}
        


    if typeof == "knife":
        if month == "Jan":
            points2009knifeJan.loc[len(points2009knifeJan)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Feb":
            points2009knifeFeb.loc[len(points2009knifeFeb)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Mar":
            points2009knifeMar.loc[len(points2009knifeMar)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Apr":
            points2009knifeApr.loc[len(points2009knifeApr)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "May":
            points2009knifeMay.loc[len(points2009knifeMay)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Jun":
            points2009knifeJun.loc[len(points2009knifeJun)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Jul":
            points2009knifeJul.loc[len(points2009knifeJul)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Aug":
            points2009knifeAug.loc[len(points2009knifeAug)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Sep":
            points2009knifeSep.loc[len(points2009knifeSep)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Oct":
            points2009knifeOct.loc[len(points2009knifeOct)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Nov":
            points2009knifeNov.loc[len(points2009knifeNov)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Dec":
            points2009knifeDec.loc[len(points2009knifeDec)] = {"loc": Point(xVals[i], yVals[i])}

    i += 1



points2008gunJan = pd.DataFrame(columns=['loc'])
points2008gunFeb = pd.DataFrame(columns=['loc'])
points2008gunMar = pd.DataFrame(columns=['loc'])
points2008gunApr = pd.DataFrame(columns=['loc'])
points2008gunMay = pd.DataFrame(columns=['loc'])
points2008gunJun = pd.DataFrame(columns=['loc'])
points2008gunJul = pd.DataFrame(columns=['loc'])
points2008gunAug = pd.DataFrame(columns=['loc'])
points2008gunSep = pd.DataFrame(columns=['loc'])
points2008gunOct = pd.DataFrame(columns=['loc'])
points2008gunNov = pd.DataFrame(columns=['loc'])
points2008gunDec = pd.DataFrame(columns=['loc'])

points2008knifeJan = pd.DataFrame(columns=['loc'])
points2008knifeFeb = pd.DataFrame(columns=['loc'])
points2008knifeMar = pd.DataFrame(columns=['loc'])
points2008knifeApr = pd.DataFrame(columns=['loc'])
points2008knifeMay = pd.DataFrame(columns=['loc'])
points2008knifeJun = pd.DataFrame(columns=['loc'])
points2008knifeJul = pd.DataFrame(columns=['loc'])
points2008knifeAug = pd.DataFrame(columns=['loc'])
points2008knifeSep = pd.DataFrame(columns=['loc'])
points2008knifeOct = pd.DataFrame(columns=['loc'])
points2008knifeNov = pd.DataFrame(columns=['loc'])
points2008knifeDec = pd.DataFrame(columns=['loc'])

weap2008 = pd.read_csv("NewWeaponVio2008.csv")

xVals = list(weap2008["Longitude"])
yVals = list(weap2008["Latitude"])
types = list(weap2008["WeapType"])
months = list(weap2008["Month"])
i = 0

for xVal, yVal, typeof, month in zip(xVals, yVals, types, months):

    if typeof == "gun":
        if month == "Jan":
            points2008gunJan.loc[len(points2008gunJan)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Feb":
            points2008gunFeb.loc[len(points2008gunFeb)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Mar":
            points2008gunMar.loc[len(points2008gunMar)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Apr":
            points2008gunApr.loc[len(points2008gunApr)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "May":
            points2008gunMay.loc[len(points2008gunMay)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Jun":
            points2008gunJun.loc[len(points2008gunJun)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Jul":
            points2008gunJul.loc[len(points2008gunJul)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Aug":
            points2008gunAug.loc[len(points2008gunAug)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Sep":
            points2008gunSep.loc[len(points2008gunSep)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Oct":
            points2008gunOct.loc[len(points2008gunOct)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Nov":
            points2008gunNov.loc[len(points2008gunNov)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Dec":
            points2008gunDec.loc[len(points2008gunDec)] = {"loc": Point(xVals[i], yVals[i])}
        


    if typeof == "knife":
        if month == "Jan":
            points2008knifeJan.loc[len(points2008knifeJan)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Feb":
            points2008knifeFeb.loc[len(points2008knifeFeb)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Mar":
            points2008knifeMar.loc[len(points2008knifeMar)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Apr":
            points2008knifeApr.loc[len(points2008knifeApr)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "May":
            points2008knifeMay.loc[len(points2008knifeMay)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Jun":
            points2008knifeJun.loc[len(points2008knifeJun)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Jul":
            points2008knifeJul.loc[len(points2008knifeJul)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Aug":
            points2008knifeAug.loc[len(points2008knifeAug)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Sep":
            points2008knifeSep.loc[len(points2008knifeSep)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Oct":
            points2008knifeOct.loc[len(points2008knifeOct)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Nov":
            points2008knifeNov.loc[len(points2008knifeNov)] = {"loc": Point(xVals[i], yVals[i])}
        elif month == "Dec":
            points2008knifeDec.loc[len(points2008knifeDec)] = {"loc": Point(xVals[i], yVals[i])}

    i += 1

# %%
len(points2018gunJan)
# Out:
# 12

# %%
points2008gunDec
# Out:
#                                             loc
# 0  POINT (-89.38620917195293 43.14020634498114)
# 1  POINT (-89.47982823664154 43.03091501625707)
# 2  POINT (-89.50248094344788 43.06637629808414)
# 3  POINT (-89.38178861113886 43.02769693872156)
# 4  POINT (-89.39595701979819 43.07090952434309)
# 5  POINT (-89.29105376241833 43.09193877755882)

# %%
# per month by year and by weapon type

city = geopandas.read_file("city")
lakes = geopandas.read_file("lakes")



def update_func(frame_num):
    
    if frame_num == 0:
        gunpoints = geopandas.GeoDataFrame(points2008gunJan, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2008knifeJan, geometry="loc")
        date = "Jan 2008"
    elif frame_num == 1:
        gunpoints = geopandas.GeoDataFrame(points2008gunFeb, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2008knifeFeb, geometry="loc")
        date = "Feb 2008"
    elif frame_num == 2:
        gunpoints = geopandas.GeoDataFrame(points2008gunMar, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2008knifeMar, geometry="loc")
        date = "Mar 2008"
    elif frame_num == 3:
        gunpoints = geopandas.GeoDataFrame(points2008gunApr, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2008knifeApr, geometry="loc")
        date = "Apr 2008"
    elif frame_num == 4:
        gunpoints = geopandas.GeoDataFrame(points2008gunMay, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2008knifeMay, geometry="loc")
        date = "May 2008"
    elif frame_num == 5:
        gunpoints = geopandas.GeoDataFrame(points2008gunJun, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2008knifeJun, geometry="loc")
        date = "Jun 2008"
    elif frame_num == 6:
        gunpoints = geopandas.GeoDataFrame(points2008gunJul, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2008knifeJul, geometry="loc")
        date = "Jul 2008"
    elif frame_num == 7:
        gunpoints = geopandas.GeoDataFrame(points2008gunAug, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2008knifeAug, geometry="loc")
        date = "Aug 2008"
    elif frame_num == 8:
        gunpoints = geopandas.GeoDataFrame(points2008gunSep, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2008knifeSep, geometry="loc")
        date = "Sep 2008"
    elif frame_num == 9:
        gunpoints = geopandas.GeoDataFrame(points2008gunOct, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2008knifeOct, geometry="loc")
        date = "Oct 2008"
    elif frame_num == 10:
        gunpoints = geopandas.GeoDataFrame(points2008gunNov, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2008knifeNov, geometry="loc")
        date = "Nov 2008"
    elif frame_num == 11:
        gunpoints = geopandas.GeoDataFrame(points2008gunDec, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2008knifeDec, geometry="loc")
        date = "Dec 2008"
    elif frame_num == 12:
        gunpoints = geopandas.GeoDataFrame(points2009gunJan, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2009knifeJan, geometry="loc")
        date = "Jan 2009"
    elif frame_num == 13:
        gunpoints = geopandas.GeoDataFrame(points2009gunFeb, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2009knifeFeb, geometry="loc")
        date = "Feb 2009"
    elif frame_num == 14:
        gunpoints = geopandas.GeoDataFrame(points2009gunMar, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2009knifeMar, geometry="loc")
        date = "Mar 2009"
    elif frame_num == 15:
        gunpoints = geopandas.GeoDataFrame(points2009gunApr, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2009knifeApr, geometry="loc")
        date = "Apr 2009"
    elif frame_num == 16:
        gunpoints = geopandas.GeoDataFrame(points2009gunMay, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2009knifeMay, geometry="loc")
        date = "May 2009"
    elif frame_num == 17:
        gunpoints = geopandas.GeoDataFrame(points2009gunJun, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2009knifeJun, geometry="loc")
        date = "Jun 2009"
    elif frame_num == 18:
        gunpoints = geopandas.GeoDataFrame(points2009gunJul, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2009knifeJul, geometry="loc")
        date = "Jul 2009"
    elif frame_num == 19:
        gunpoints = geopandas.GeoDataFrame(points2009gunAug, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2009knifeAug, geometry="loc")
        date = "Aug 2009"
    elif frame_num == 20:
        gunpoints = geopandas.GeoDataFrame(points2009gunSep, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2009knifeSep, geometry="loc")
        date = "Sep 2009"
    elif frame_num == 21:
        gunpoints = geopandas.GeoDataFrame(points2009gunOct, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2009knifeOct, geometry="loc")
        date = "Oct 2009"
    elif frame_num == 22:
        gunpoints = geopandas.GeoDataFrame(points2009gunNov, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2009knifeNov, geometry="loc")
        date = "Nov 2009"
    elif frame_num == 23:
        gunpoints = geopandas.GeoDataFrame(points2009gunDec, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2009knifeDec, geometry="loc")
        date = "Dec 2009"
    elif frame_num == 24:
        gunpoints = geopandas.GeoDataFrame(points2010gunJan, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2010knifeJan, geometry="loc")
        date = "Jan 2010"
    elif frame_num == 25:
        gunpoints = geopandas.GeoDataFrame(points2010gunFeb, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2010knifeFeb, geometry="loc")
        date = "Feb 2010"
    elif frame_num == 26:
        gunpoints = geopandas.GeoDataFrame(points2010gunMar, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2010knifeMar, geometry="loc")
        date = "Mar 2010"
    elif frame_num == 27:
        gunpoints = geopandas.GeoDataFrame(points2010gunApr, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2010knifeApr, geometry="loc")
        date = "Apr 2010"
    elif frame_num == 28:
        gunpoints = geopandas.GeoDataFrame(points2010gunMay, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2010knifeMay, geometry="loc")
        date = "May 2010"
    elif frame_num == 29:
        gunpoints = geopandas.GeoDataFrame(points2010gunJun, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2010knifeJun, geometry="loc")
        date = "Jun 2010"
    elif frame_num == 30:
        gunpoints = geopandas.GeoDataFrame(points2010gunJul, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2010knifeJul, geometry="loc")
        date = "Jul 2010"
    elif frame_num == 31:
        gunpoints = geopandas.GeoDataFrame(points2010gunAug, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2010knifeAug, geometry="loc")
        date = "Aug 2010"
    elif frame_num == 32:
        gunpoints = geopandas.GeoDataFrame(points2010gunSep, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2010knifeSep, geometry="loc")
        date = "Sep 2010"
    elif frame_num == 33:
        gunpoints = geopandas.GeoDataFrame(points2010gunOct, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2010knifeOct, geometry="loc")
        date = "Oct 2010"
    elif frame_num == 34:
        gunpoints = geopandas.GeoDataFrame(points2010gunNov, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2010knifeNov, geometry="loc")
        date = "Nov 2010"
    elif frame_num == 35:
        gunpoints = geopandas.GeoDataFrame(points2010gunDec, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2010knifeDec, geometry="loc")
        date = "Dec 2010"
    elif frame_num == 36:
        gunpoints = geopandas.GeoDataFrame(points2011gunJan, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2011knifeJan, geometry="loc")
        date = "Jan 2011"
    elif frame_num == 37:
        gunpoints = geopandas.GeoDataFrame(points2011gunFeb, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2011knifeFeb, geometry="loc")
        date = "Feb 2011"
    elif frame_num == 38:
        gunpoints = geopandas.GeoDataFrame(points2011gunMar, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2011knifeMar, geometry="loc")
        date = "Mar 2011"
    elif frame_num == 39:
        gunpoints = geopandas.GeoDataFrame(points2011gunApr, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2011knifeApr, geometry="loc")
        date = "Apr 2011"
    elif frame_num == 40:
        gunpoints = geopandas.GeoDataFrame(points2011gunMay, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2011knifeMay, geometry="loc")
        date = "May 2011"
    elif frame_num == 41:
        gunpoints = geopandas.GeoDataFrame(points2011gunJun, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2011knifeJun, geometry="loc")
        date = "Jun 2011"
    elif frame_num == 42:
        gunpoints = geopandas.GeoDataFrame(points2011gunJul, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2011knifeJul, geometry="loc")
        date = "Jul 2011"
    elif frame_num == 43:
        gunpoints = geopandas.GeoDataFrame(points2011gunAug, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2011knifeAug, geometry="loc")
        date = "Aug 2011"
    elif frame_num == 44:
        gunpoints = geopandas.GeoDataFrame(points2011gunSep, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2011knifeSep, geometry="loc")
        date = "Sep 2011"
    elif frame_num == 45:
        gunpoints = geopandas.GeoDataFrame(points2011gunOct, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2011knifeOct, geometry="loc")
        date = "Oct 2011"
    elif frame_num == 46:
        gunpoints = geopandas.GeoDataFrame(points2011gunNov, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2011knifeNov, geometry="loc")
        date = "Nov 2011"
    elif frame_num == 47:
        gunpoints = geopandas.GeoDataFrame(points2011gunDec, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2011knifeDec, geometry="loc")
        date = "Dec 2011"
    elif frame_num == 48:
        gunpoints = geopandas.GeoDataFrame(points2012gunJan, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2012knifeJan, geometry="loc")
        date = "Jan 2012"
    elif frame_num == 49:
        gunpoints = geopandas.GeoDataFrame(points2012gunFeb, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2012knifeFeb, geometry="loc")
        date = "Feb 2012"
    elif frame_num == 50:
        gunpoints = geopandas.GeoDataFrame(points2012gunMar, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2012knifeMar, geometry="loc")
        date = "Mar 2012"
    elif frame_num == 51:
        gunpoints = geopandas.GeoDataFrame(points2012gunApr, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2012knifeApr, geometry="loc")
        date = "Apr 2012"
    elif frame_num == 52:
        gunpoints = geopandas.GeoDataFrame(points2012gunMay, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2012knifeMay, geometry="loc")
        date = "May 2012"
    elif frame_num == 53:
        gunpoints = geopandas.GeoDataFrame(points2012gunJun, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2012knifeJun, geometry="loc")
        date = "Jun 2012"
    elif frame_num == 54:
        gunpoints = geopandas.GeoDataFrame(points2012gunJul, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2012knifeJul, geometry="loc")
        date = "Jul 2012"
    elif frame_num == 55:
        gunpoints = geopandas.GeoDataFrame(points2012gunAug, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2012knifeAug, geometry="loc")
        date = "Aug 2012"
    elif frame_num == 56:
        gunpoints = geopandas.GeoDataFrame(points2012gunSep, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2012knifeSep, geometry="loc")
        date = "Sep 2012"
    elif frame_num == 57:
        gunpoints = geopandas.GeoDataFrame(points2012gunOct, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2012knifeOct, geometry="loc")
        date = "Oct 2012"
    elif frame_num == 58:
        gunpoints = geopandas.GeoDataFrame(points2012gunNov, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2012knifeNov, geometry="loc")
        date = "Nov 2012"
    elif frame_num == 59:
        gunpoints = geopandas.GeoDataFrame(points2012gunDec, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2012knifeDec, geometry="loc")
        date = "Dec 2012"
    elif frame_num == 60:
        gunpoints = geopandas.GeoDataFrame(points2013gunJan, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2013knifeJan, geometry="loc")
        date = "Jan 2013"
    elif frame_num == 61:
        gunpoints = geopandas.GeoDataFrame(points2013gunFeb, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2013knifeFeb, geometry="loc")
        date = "Feb 2013"
    elif frame_num == 62:
        gunpoints = geopandas.GeoDataFrame(points2013gunMar, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2013knifeMar, geometry="loc")
        date = "Mar 2013"
    elif frame_num == 63:
        gunpoints = geopandas.GeoDataFrame(points2013gunApr, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2013knifeApr, geometry="loc")
        date = "Apr 2013"
    elif frame_num == 64:
        gunpoints = geopandas.GeoDataFrame(points2013gunMay, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2013knifeMay, geometry="loc")
        date = "May 2013"
    elif frame_num == 65:
        gunpoints = geopandas.GeoDataFrame(points2013gunJun, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2013knifeJun, geometry="loc")
        date = "Jun 2013"
    elif frame_num == 66:
        gunpoints = geopandas.GeoDataFrame(points2013gunJul, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2013knifeJul, geometry="loc")
        date = "Jul 2013"
    elif frame_num == 67:
        gunpoints = geopandas.GeoDataFrame(points2013gunAug, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2013knifeAug, geometry="loc")
        date = "Aug 2013"
    elif frame_num == 68:
        gunpoints = geopandas.GeoDataFrame(points2013gunSep, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2013knifeSep, geometry="loc")
        date = "Sep 2013"
    elif frame_num == 69:
        gunpoints = geopandas.GeoDataFrame(points2013gunOct, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2013knifeOct, geometry="loc")
        date = "Oct 2013"
    elif frame_num == 70:
        gunpoints = geopandas.GeoDataFrame(points2013gunNov, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2013knifeNov, geometry="loc")
        date = "Nov 2013"
    elif frame_num == 71:
        gunpoints = geopandas.GeoDataFrame(points2013gunDec, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2013knifeDec, geometry="loc")
        date = "Dec 2013"
    elif frame_num == 72:
        gunpoints = geopandas.GeoDataFrame(points2014gunJan, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2014knifeJan, geometry="loc")
        date = "Jan 2014"
    elif frame_num == 73:
        gunpoints = geopandas.GeoDataFrame(points2014gunFeb, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2014knifeFeb, geometry="loc")
        date = "Feb 2014"
    elif frame_num == 74:
        gunpoints = geopandas.GeoDataFrame(points2014gunMar, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2014knifeMar, geometry="loc")
        date = "Mar 2014"
    elif frame_num == 75:
        gunpoints = geopandas.GeoDataFrame(points2014gunApr, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2014knifeApr, geometry="loc")
        date = "Apr 2014"
    elif frame_num == 76:
        gunpoints = geopandas.GeoDataFrame(points2014gunMay, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2014knifeMay, geometry="loc")
        date = "May 2014"
    elif frame_num == 77:
        gunpoints = geopandas.GeoDataFrame(points2014gunJun, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2014knifeJun, geometry="loc")
        date = "Jun 2014"
    elif frame_num == 78:
        gunpoints = geopandas.GeoDataFrame(points2014gunJul, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2014knifeJul, geometry="loc")
        date = "Jul 2014"
    elif frame_num == 79:
        gunpoints = geopandas.GeoDataFrame(points2014gunAug, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2014knifeAug, geometry="loc")
        date = "Aug 2014"
    elif frame_num == 80:
        gunpoints = geopandas.GeoDataFrame(points2014gunSep, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2014knifeSep, geometry="loc")
        date = "Sep 2014"
    elif frame_num == 81:
        gunpoints = geopandas.GeoDataFrame(points2014gunOct, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2014knifeOct, geometry="loc")
        date = "Oct 2014"
    elif frame_num == 82:
        gunpoints = geopandas.GeoDataFrame(points2014gunNov, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2014knifeNov, geometry="loc")
        date = "Nov 2014"
    elif frame_num == 83:
        gunpoints = geopandas.GeoDataFrame(points2014gunDec, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2014knifeDec, geometry="loc")
        date = "Dec 2014"
    elif frame_num == 84:
        gunpoints = geopandas.GeoDataFrame(points2015gunJan, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2015knifeJan, geometry="loc")
        date = "Jan 2015"
    elif frame_num == 85:
        gunpoints = geopandas.GeoDataFrame(points2015gunFeb, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2015knifeFeb, geometry="loc")
        date = "Feb 2015"
    elif frame_num == 86:
        gunpoints = geopandas.GeoDataFrame(points2015gunMar, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2015knifeMar, geometry="loc")
        date = "Mar 2015"
    elif frame_num == 87:
        gunpoints = geopandas.GeoDataFrame(points2015gunApr, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2015knifeApr, geometry="loc")
        date = "Apr 2015"
    elif frame_num == 88:
        gunpoints = geopandas.GeoDataFrame(points2015gunMay, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2015knifeMay, geometry="loc")
        date = "May 2015"
    elif frame_num == 89:
        gunpoints = geopandas.GeoDataFrame(points2015gunJun, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2015knifeJun, geometry="loc")
        date = "Jun 2015"
    elif frame_num == 90:
        gunpoints = geopandas.GeoDataFrame(points2015gunJul, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2015knifeJul, geometry="loc")
        date = "Jul 2015"
    elif frame_num == 91:
        gunpoints = geopandas.GeoDataFrame(points2015gunAug, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2015knifeAug, geometry="loc")
        date = "Aug 2015"
    elif frame_num == 92:
        gunpoints = geopandas.GeoDataFrame(points2015gunSep, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2015knifeSep, geometry="loc")
        date = "Sep 2015"
    elif frame_num == 93:
        gunpoints = geopandas.GeoDataFrame(points2015gunOct, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2015knifeOct, geometry="loc")
        date = "Oct 2015"
    elif frame_num == 94:
        gunpoints = geopandas.GeoDataFrame(points2015gunNov, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2015knifeNov, geometry="loc")
        date = "Nov 2015"
    elif frame_num == 95:
        gunpoints = geopandas.GeoDataFrame(points2015gunDec, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2015knifeDec, geometry="loc")
        date = "Dec 2015"
    elif frame_num == 96:
        gunpoints = geopandas.GeoDataFrame(points2016gunJan, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2016knifeJan, geometry="loc")
        date = "Jan 2016"
    elif frame_num == 97:
        gunpoints = geopandas.GeoDataFrame(points2016gunFeb, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2016knifeFeb, geometry="loc")
        date = "Feb 2016"
    elif frame_num == 98:
        gunpoints = geopandas.GeoDataFrame(points2016gunMar, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2016knifeMar, geometry="loc")
        date = "Mar 2016"
    elif frame_num == 99:
        gunpoints = geopandas.GeoDataFrame(points2016gunApr, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2016knifeApr, geometry="loc")
        date = "Apr 2016"
    elif frame_num == 100:
        gunpoints = geopandas.GeoDataFrame(points2016gunMay, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2016knifeMay, geometry="loc")
        date = "May 2016"
    elif frame_num == 101:
        gunpoints = geopandas.GeoDataFrame(points2016gunJun, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2016knifeJun, geometry="loc")
        date = "Jun 2016"
    elif frame_num == 102:
        gunpoints = geopandas.GeoDataFrame(points2016gunJul, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2016knifeJul, geometry="loc")
        date = "Jul 2016"
    elif frame_num == 103:
        gunpoints = geopandas.GeoDataFrame(points2016gunAug, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2016knifeAug, geometry="loc")
        date = "Aug 2016"
    elif frame_num == 104:
        gunpoints = geopandas.GeoDataFrame(points2016gunSep, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2016knifeSep, geometry="loc")
        date = "Sep 2016"
    elif frame_num == 105:
        gunpoints = geopandas.GeoDataFrame(points2016gunOct, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2016knifeOct, geometry="loc")
        date = "Oct 2016"
    elif frame_num == 106:
        gunpoints = geopandas.GeoDataFrame(points2016gunNov, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2016knifeNov, geometry="loc")
        date = "Nov 2016"
    elif frame_num == 107:
        gunpoints = geopandas.GeoDataFrame(points2016gunDec, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2016knifeDec, geometry="loc")
        date = "Dec 2016"
    elif frame_num == 108:
        gunpoints = geopandas.GeoDataFrame(points2017gunJan, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2017knifeJan, geometry="loc")
        date = "Jan 2017"
    elif frame_num == 109:
        gunpoints = geopandas.GeoDataFrame(points2017gunFeb, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2017knifeFeb, geometry="loc")
        date = "Feb 2017"
    elif frame_num == 110:
        gunpoints = geopandas.GeoDataFrame(points2017gunMar, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2017knifeMar, geometry="loc")
        date = "Mar 2017"
    elif frame_num == 111:
        gunpoints = geopandas.GeoDataFrame(points2017gunApr, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2017knifeApr, geometry="loc")
        date = "Apr 2017"
    elif frame_num == 112:
        gunpoints = geopandas.GeoDataFrame(points2017gunMay, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2017knifeMay, geometry="loc")
        date = "May 2017"
    elif frame_num == 113:
        gunpoints = geopandas.GeoDataFrame(points2017gunJun, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2017knifeJun, geometry="loc")
        date = "Jun 2017"
    elif frame_num == 114:
        gunpoints = geopandas.GeoDataFrame(points2017gunJul, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2017knifeJul, geometry="loc")
        date = "Jul 2017"
    elif frame_num == 115:
        gunpoints = geopandas.GeoDataFrame(points2017gunAug, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2017knifeAug, geometry="loc")
        date = "Aug 2017"
    elif frame_num == 116:
        gunpoints = geopandas.GeoDataFrame(points2017gunSep, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2017knifeSep, geometry="loc")
        date = "Sep 2017"
    elif frame_num == 117:
        gunpoints = geopandas.GeoDataFrame(points2017gunOct, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2017knifeOct, geometry="loc")
        date = "Oct 2017"
    elif frame_num == 118:
        gunpoints = geopandas.GeoDataFrame(points2017gunNov, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2017knifeNov, geometry="loc")
        date = "Nov 2017"
    elif frame_num == 119:
        gunpoints = geopandas.GeoDataFrame(points2017gunDec, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2017knifeDec, geometry="loc")
        date = "Dec 2017"
    elif frame_num == 120:
        gunpoints = geopandas.GeoDataFrame(points2018gunJan, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2018knifeJan, geometry="loc")
        date = "Jan 2018"
    elif frame_num == 121:
        gunpoints = geopandas.GeoDataFrame(points2018gunFeb, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2018knifeFeb, geometry="loc")
        date = "Feb 2018"
    elif frame_num == 122:
        gunpoints = geopandas.GeoDataFrame(points2018gunMar, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2018knifeMar, geometry="loc")
        date = "Mar 2018"
    elif frame_num == 123:
        gunpoints = geopandas.GeoDataFrame(points2018gunApr, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2018knifeApr, geometry="loc")
        date = "Apr 2018"
    elif frame_num == 124:
        gunpoints = geopandas.GeoDataFrame(points2018gunMay, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2018knifeMay, geometry="loc")
        date = "May 2018"
    elif frame_num == 125:
        gunpoints = geopandas.GeoDataFrame(points2018gunJun, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2018knifeJun, geometry="loc")
        date = "Jun 2018"
    elif frame_num == 126:
        gunpoints = geopandas.GeoDataFrame(points2018gunJul, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2018knifeJul, geometry="loc")
        date = "Jul 2018"
    elif frame_num == 127:
        gunpoints = geopandas.GeoDataFrame(points2018gunAug, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2018knifeAug, geometry="loc")
        date = "Aug 2018"
    elif frame_num == 128:
        gunpoints = geopandas.GeoDataFrame(points2018gunSep, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2018knifeSep, geometry="loc")
        date = "Sep 2018"
    elif frame_num == 129:
        gunpoints = geopandas.GeoDataFrame(points2018gunOct, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2018knifeOct, geometry="loc")
        date = "Oct 2018"
    elif frame_num == 130:
        gunpoints = geopandas.GeoDataFrame(points2018gunNov, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2018knifeNov, geometry="loc")
        date = "Nov 2018"
    elif frame_num == 131:
        gunpoints = geopandas.GeoDataFrame(points2018gunDec, geometry="loc")
        knifepoints = geopandas.GeoDataFrame(points2018knifeDec, geometry="loc")
        date = "Dec 2018"

    

    ax.cla() # clears plot area (try removing it!)
    city.plot(color="lightgray", ax=ax)
    lakes.plot(color="darkgray", ax=ax)
    gunpoints.plot(color="red", marker="x", ax=ax)
    knifepoints.plot(color="blue", marker="x", ax=ax)
    ax.set_axis_off()
    
    ax.text(-89.384054, 43.015, date)
    ax.text(-89.384054, 43.008, "Blue for knife")
    ax.text(-89.384054, 43.001, "Red for gun")
    

with open("WeaponViolationByMonth.html", "w") as f:
    f.write(animation.FuncAnimation(fig, update_func, frames=10, interval=2000).to_html5_video())
# Out:
# /usr/local/lib/python3.7/site-packages/geopandas/plotting.py:418: UserWarning: The GeoDataFrame you are attempting to plot is empty. Nothing has been displayed.
#   "empty. Nothing has been displayed.", UserWarning)

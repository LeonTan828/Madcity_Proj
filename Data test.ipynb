# %%
import pandas

# %%
lib_loc = pandas.read_csv("Parks.csv")
lib_loc
# Out:
#      OBJECTID                       Accela_ID Park_ID            Type  \
# 0        5538             Spring Harbor Beach    441N            MINI
# 1        5539    Dickinson St (So) Street End    128T      TRAFFICWAY
# 2        5540            Sherwood Forest Park    569N            MINI
# 3        5541            Midtown Commons Park    783A    NEIGHBORHOOD
# 4        5542                Swallowtail Park    771N            MINI
# 5        5543                 Bear Mound Park    111S      OPEN SPACE
# 6        5544          Bitzer Family Preserve    989E    CONSERVATION
# 7        5545                  Bernie's Beach    107N            MINI
# 8        5546               Pumping Station 8    225S           OTHER
# 9        5547                 Sauk Creek Park    667N    NEIGHBORHOOD
# 10       5548       Stevens Street Playground    269N            MINI
# 11       5549                     Filene Park    118P            MINI
# ...

# %%
lib_loc.iloc[:, 0:2]
# Out:
#      OBJECTID                       Accela_ID
# 0        5538             Spring Harbor Beach
# 1        5539    Dickinson St (So) Street End
# 2        5540            Sherwood Forest Park
# 3        5541            Midtown Commons Park
# 4        5542                Swallowtail Park
# 5        5543                 Bear Mound Park
# 6        5544          Bitzer Family Preserve
# 7        5545                  Bernie's Beach
# 8        5546               Pumping Station 8
# 9        5547                 Sauk Creek Park
# 10       5548       Stevens Street Playground
# 11       5549                     Filene Park
# 12       5550                 Hill Creek Park
# 13       5551           Westhaven Trails Park
# 14       5552             Nautilus Point Park
# 15       5553                     Badger Park
# 16       5554               Meadow Ridge Park
# 17       5555                   Marshall Park
# 18       5556             Highland Manor Park
# ...

# %%
lib_loc = lib_loc.iloc[:, 0:2]
lib_loc
# Out:
#      OBJECTID                       Accela_ID
# 0        5538             Spring Harbor Beach
# 1        5539    Dickinson St (So) Street End
# 2        5540            Sherwood Forest Park
# 3        5541            Midtown Commons Park
# 4        5542                Swallowtail Park
# 5        5543                 Bear Mound Park
# 6        5544          Bitzer Family Preserve
# 7        5545                  Bernie's Beach
# 8        5546               Pumping Station 8
# 9        5547                 Sauk Creek Park
# 10       5548       Stevens Street Playground
# 11       5549                     Filene Park
# 12       5550                 Hill Creek Park
# 13       5551           Westhaven Trails Park
# 14       5552             Nautilus Point Park
# 15       5553                     Badger Park
# 16       5554               Meadow Ridge Park
# 17       5555                   Marshall Park
# 18       5556             Highland Manor Park
# ...

# %%
park = pandas.read_json("Parks.geojson.json")

# %%
park
# Out:
#                   type                                           features
# 0    FeatureCollection  {'type': 'Feature', 'properties': {'OBJECTID':...
# 1    FeatureCollection  {'type': 'Feature', 'properties': {'OBJECTID':...
# 2    FeatureCollection  {'type': 'Feature', 'properties': {'OBJECTID':...
# 3    FeatureCollection  {'type': 'Feature', 'properties': {'OBJECTID':...
# 4    FeatureCollection  {'type': 'Feature', 'properties': {'OBJECTID':...
# 5    FeatureCollection  {'type': 'Feature', 'properties': {'OBJECTID':...
# 6    FeatureCollection  {'type': 'Feature', 'properties': {'OBJECTID':...
# 7    FeatureCollection  {'type': 'Feature', 'properties': {'OBJECTID':...
# 8    FeatureCollection  {'type': 'Feature', 'properties': {'OBJECTID':...
# 9    FeatureCollection  {'type': 'Feature', 'properties': {'OBJECTID':...
# 10   FeatureCollection  {'type': 'Feature', 'properties': {'OBJECTID':...
# 11   FeatureCollection  {'type': 'Feature', 'properties': {'OBJECTID':...
# ...

# %%
park.iloc[1,1]
# Out:
# {'type': 'Feature',
#  'properties': {'OBJECTID': 5539,
#   'Accela_ID': 'Dickinson St (So) Street End',
#   'Park_ID': '128T',
#   'Type': 'TRAFFICWAY',
#   'Mstn_level': 'CityPark_Trafficway',
#   'Acreage': 0.09,
#   'Park_Name': 'Dickinson Street (South) Street End',
#   'Polygon_count': 1,
#   'SHAPESTArea': 4093.1683959960938,
#   'SHAPESTLength': 256.8107025990336},
#  'geometry': {'type': 'Polygon',
#   'coordinates': [[[-89.35697929466548, 43.08275526625562],
#     [-89.3567774344938, 43.08286021445773],
#     [-89.35695342164868, 43.08299082064096],
#     [-89.35713303846964, 43.08287176479709],
#     [-89.35697929466548, 43.08275526625562]]]}}

# %%
import pandas
import math

# %%
incidentRep = pandas.read_csv("Police_Incident_Reports.csv")
incidentRep
# Out:
#        IncidentID                                     IncidentType  \
# 0            8400                                          Robbery
# 1            8401  Weapons Violation
# 2            8403  Robbery
# 3            8404  Non-Residential Burglary
# 4            8405  Robbery
# 5            8406  Robbery
# 6            8407  Intoxicated Driver
# 7            8408  Residential Burglary
# 8            8409  Battery
# 9            8410  Battery
# 10           8411  Accident - Injury
# 11           8412  Robbery
# 12           8413  Robbery
# 13           8414  Weapons Violation
# 14           8415  Battery
# 15           8416  Accident - Injury
# 16           8417  Robbery
# 17           8418  Accident - Injury
# 18           8419  Sexual Assault
# 19           8420  Information
# 20           8421  Exposure
# 21           8422  Arson Investigation
# 22           8423  Robbery
# 23           8424  Information
# 24           8426  Enticement/Kidnapping
# ...

# %%
# 2018
y2018 = incidentRep.loc[0:924, ['IncidentType', 'IncidentDate', 'Details']]
y2018
# Out:
#                                         IncidentType  \
# 0                                            Robbery
# 1    Weapons Violation
# 2    Robbery
# 3    Non-Residential Burglary
# 4    Robbery
# 5    Robbery
# 6    Intoxicated Driver
# 7    Residential Burglary
# 8    Battery
# 9    Battery
# 10   Accident - Injury
# 11   Robbery
# 12   Robbery
# 13   Weapons Violation
# 14   Battery
# 15   Accident - Injury
# 16   Robbery
# 17   Accident - Injury
# 18   Sexual Assault
# 19   Information
# 20   Exposure
# 21   Arson Investigation
# 22   Robbery
# 23   Information
# 24   Enticement/Kidnapping
# 25   Non-Residential Burglary
# 26   Robbery
# 27   Animal Complaint - Stray
# 28   Strong Armed Robbery
# 29   Robbery
# ..                                               ...
# 895                                  Arrested Person
# 896                                Accident - Injury
# 897                                   Traffic Arrest
# ...

# %%
currRow = 0 

for i, row in incidentRep.iterrows():
    newstr = row["IncidentDate"][:4]
    if newstr == "2018":
        y2018.loc[currRow, "IncidentType"] = row["IncidentType"]
        y2018.loc[currRow, "IncidentDate"] = row["IncidentDate"]
        y2018.loc[currRow, "Details"] = row["Details"]
        currRow = currRow + 1
        
y2018
# Out:
#                     IncidentType              IncidentDate  \
# 0                          Theft  2018-08-14T04:59:00.000Z
# 1                        Robbery  2018-08-15T18:28:00.000Z
# 2             Drug Investigation  2018-08-15T08:00:00.000Z
# 3                 Injured Person  2018-08-17T04:03:00.000Z
# 4                    Information  2018-08-19T16:25:00.000Z
# 5              Weapons Violation  2018-08-19T21:47:00.000Z
# 6                        Robbery  2018-01-01T12:16:00.000Z
# 7                        Robbery  2018-01-01T16:30:00.000Z
# 8                        Robbery  2018-01-01T16:30:00.000Z
# 9                   Check Person  2018-01-01T12:06:00.000Z
# 10             Weapons Violation  2018-01-01T01:13:00.000Z
# 11                       Robbery  2018-01-02T19:04:00.000Z
# 12             Weapons Violation  2018-01-02T18:46:00.000Z
# 13       Domestic/Family Trouble  2018-01-02T20:00:00.000Z
# 14   Intoxicated/Impaired Driver  2018-01-02T17:48:00.000Z
# ...

# %%
# 2018 WV only
y2018wv = y2018.loc[0:215, ['IncidentType', 'IncidentDate', 'Details']]
y2018wv
# Out:
#                     IncidentType              IncidentDate  \
# 0                          Theft  2018-08-14T04:59:00.000Z
# 1                        Robbery  2018-08-15T18:28:00.000Z
# 2             Drug Investigation  2018-08-15T08:00:00.000Z
# 3                 Injured Person  2018-08-17T04:03:00.000Z
# 4                    Information  2018-08-19T16:25:00.000Z
# 5              Weapons Violation  2018-08-19T21:47:00.000Z
# 6                        Robbery  2018-01-01T12:16:00.000Z
# 7                        Robbery  2018-01-01T16:30:00.000Z
# 8                        Robbery  2018-01-01T16:30:00.000Z
# 9                   Check Person  2018-01-01T12:06:00.000Z
# 10             Weapons Violation  2018-01-01T01:13:00.000Z
# 11                       Robbery  2018-01-02T19:04:00.000Z
# 12             Weapons Violation  2018-01-02T18:46:00.000Z
# 13       Domestic/Family Trouble  2018-01-02T20:00:00.000Z
# 14   Intoxicated/Impaired Driver  2018-01-02T17:48:00.000Z
# ...

# %%
currRow = 0

for i, row in y2018.iterrows():
    newstr = row["IncidentDate"][:4]
    currInc = row['IncidentType']
    
    if currInc == "Weapons Violation":
        if newstr == "2018":
            y2018wv.loc[currRow, "IncidentType"] = row["IncidentType"]
            y2018wv.loc[currRow, "IncidentDate"] = row["IncidentDate"]
            y2018wv.loc[currRow, "Details"] = row["Details"]
            currRow = currRow + 1
            
y2018wv
# Out:
#           IncidentType              IncidentDate  \
# 0    Weapons Violation  2018-08-19T21:47:00.000Z
# 1    Weapons Violation  2018-01-01T01:13:00.000Z
# 2    Weapons Violation  2018-01-02T18:46:00.000Z
# 3    Weapons Violation  2018-01-02T11:55:00.000Z
# 4    Weapons Violation  2018-01-09T20:08:00.000Z
# 5    Weapons Violation  2018-01-09T21:35:00.000Z
# 6    Weapons Violation  2018-01-17T23:51:00.000Z
# 7    Weapons Violation  2018-01-18T02:34:00.000Z
# 8    Weapons Violation  2018-01-17T15:04:00.000Z
# 9    Weapons Violation  2018-01-18T21:52:00.000Z
# 10   Weapons Violation  2018-01-21T18:10:00.000Z
# 11   Weapons Violation  2018-01-22T03:37:00.000Z
# 12   Weapons Violation  2018-01-26T01:50:00.000Z
# 13   Weapons Violation  2018-01-26T23:05:00.000Z
# 14   Weapons Violation  2018-01-31T22:58:00.000Z
# 15   Weapons Violation  2018-02-02T15:30:00.000Z
# 16   Weapons Violation  2018-02-02T19:18:00.000Z
# 17   Weapons Violation  2018-02-03T00:13:00.000Z
# ...

# %%
y2018wv.loc[2, "Details"]
# Out:
# '&nbsp;A Green Avenue homeowner said the reports were so loud it sounded as if a gun was being fired right outside his living room window last evening. He dropped to the floor fearing he might be hit. In the darkness, responding officers recovered three shell casings in the roadway, but witnesses thought they heard as many as five shots. There were no immediate reports of injuries or property damage.'

# %%
knife = 0
gun = 0

for i, row in y2018wv.iterrows():
    #print(row["Details"])
    #print("\n")
    
    if "gun" in row["Details"]:
        gun += 1
        y2018wv.loc[i, "WeapType"] = "gun"
        
    elif "shots" in row["Details"]:
        gun += 1
        y2018wv.loc[i, "WeapType"] = "gun"
        
    elif "shot" in row["Details"]:
        gun += 1
        y2018wv.loc[i, "WeapType"] = "gun"
        
    elif "fired" in row["Details"]:
        gun += 1
        y2018wv.loc[i, "WeapType"] = "gun"
        
    elif "shooting" in row["Details"]:
        gun += 1
        y2018wv.loc[i, "WeapType"] = "gun"
        
    elif "knife" in row["Details"]:
        knife += 1
        y2018wv.loc[i, "WeapType"] = "knife"
        
    elif "stabbed" in row["Details"]:
        knife += 1
        y2018wv.loc[i, "WeapType"] = "knife"
        
    elif "stab" in row["Details"]:
        knife += 1
        y2018wv.loc[i, "WeapType"] = "knife"
        
    elif "cut" in row["Details"]:
        knife += 1
        y2018wv.loc[i, "WeapType"] = "knife"
        
    else:
        print(row["Details"])
        print("\n")
        
print(knife)
print(gun)
# Out:
# The MPD is seeking the public’s help in locating Armon D. Vaccaro, age 17, Madison. Vaccaro is 5’10” and 120 pounds. His address is currently unknown. The MPD’s Violent Crime Unit has a warrant to arrest Vaccaro for a recent weapons violation, and the MPD’s Burglary Crime Unit has probable cause to take him into custody for multiple burglaries. Vaccaro should be considered armed and dangerous. Anyone seeing him, or having knowledge of his whereabouts should call 911.<br />
# &nbsp;
#
#
# MPD officers responded to a residential address in the 1600 block of Beld St. for a third-hand report of a weapons violation in the residence. Officers and detectives are interviewing some of the residents who were home at the time of the weapons violation; however, the two individuals reported to have been involved in the weapons incident have not yet been located. No injuries have been reported to police as a result of this incident and the investigation is continuing at this time.
#
#
# ...

# %%
y2018wv
# Out:
#           IncidentType              IncidentDate  \
# 0    Weapons Violation  2018-08-19T21:47:00.000Z
# 1    Weapons Violation  2018-01-01T01:13:00.000Z
# 2    Weapons Violation  2018-01-02T18:46:00.000Z
# 3    Weapons Violation  2018-01-02T11:55:00.000Z
# 4    Weapons Violation  2018-01-09T20:08:00.000Z
# 5    Weapons Violation  2018-01-09T21:35:00.000Z
# 6    Weapons Violation  2018-01-17T23:51:00.000Z
# 7    Weapons Violation  2018-01-18T02:34:00.000Z
# 8    Weapons Violation  2018-01-17T15:04:00.000Z
# 9    Weapons Violation  2018-01-18T21:52:00.000Z
# 10   Weapons Violation  2018-01-21T18:10:00.000Z
# 11   Weapons Violation  2018-01-22T03:37:00.000Z
# 12   Weapons Violation  2018-01-26T01:50:00.000Z
# 13   Weapons Violation  2018-01-26T23:05:00.000Z
# 14   Weapons Violation  2018-01-31T22:58:00.000Z
# 15   Weapons Violation  2018-02-02T15:30:00.000Z
# 16   Weapons Violation  2018-02-02T19:18:00.000Z
# 17   Weapons Violation  2018-02-03T00:13:00.000Z
# ...

# %%
data = [['Gun', 0], ['Knife', 0]] 
VioType = pandas.DataFrame(data, columns = ['Type', 'Amount for 2018'])
VioType.set_index('Type', inplace = True)
VioType
# Out:
#        Amount for 2018
# Type
# Gun                  0
# Knife                0

# %%
VioType['Amount for 2017'] = VioType['Amount for 2018']
VioType['Amount for 2016'] = VioType['Amount for 2018']
VioType['Amount for 2015'] = VioType['Amount for 2018']
VioType['Amount for 2014'] = VioType['Amount for 2018']
VioType['Amount for 2013'] = VioType['Amount for 2018']
VioType['Amount for 2012'] = VioType['Amount for 2018']
VioType['Amount for 2011'] = VioType['Amount for 2018']
VioType['Amount for 2010'] = VioType['Amount for 2018']
VioType['Amount for 2009'] = VioType['Amount for 2018']
VioType['Amount for 2008'] = VioType['Amount for 2018']

VioType
# Out:
#        Amount for 2018  Amount for 2017  Amount for 2016  Amount for 2015  \
# Type
# Gun                  0                0                0                0
# Knife                0                0                0                0
#
#        Amount for 2014  Amount for 2013  Amount for 2012  Amount for 2011  \
# Type
# Gun                  0                0                0                0
# Knife                0                0                0                0
#
#        Amount for 2010  Amount for 2009  Amount for 2008
# Type
# Gun                  0                0                0
# Knife                0                0                0

# %%
VioType.loc['Gun', 'Amount for 2018'] = gun
VioType.loc['Knife', 'Amount for 2018'] = knife

# %%
VioType
# Out:
#        Amount for 2018  Amount for 2017  Amount for 2016  Amount for 2015  \
# Type
# Gun                168                0                0                0
# Knife               43                0                0                0
#
#        Amount for 2014  Amount for 2013  Amount for 2012  Amount for 2011  \
# Type
# Gun                  0                0                0                0
# Knife                0                0                0                0
#
#        Amount for 2010  Amount for 2009  Amount for 2008
# Type
# Gun                  0                0                0
# Knife                0                0                0

# %%
# 2017
y2017 = incidentRep.loc[0:846, ['IncidentType', 'IncidentDate', 'Details']]
y2017

currRow = 0 

for i, row in incidentRep.iterrows():
    newstr = row["IncidentDate"][:4]
    if newstr == "2017":
        y2017.loc[currRow, "IncidentType"] = row["IncidentType"]
        y2017.loc[currRow, "IncidentDate"] = row["IncidentDate"]
        y2017.loc[currRow, "Details"] = row["Details"]
        currRow = currRow + 1
        
y2017
# Out:
#                     IncidentType              IncidentDate  \
# 0                        Robbery  2017-12-19T22:28:00.000Z
# 1                        Robbery  2017-12-19T23:34:00.000Z
# 2              Weapons Violation  2017-01-01T02:40:00.000Z
# 3              Weapons Violation  2017-01-01T19:13:00.000Z
# 4              Weapons Violation  2017-01-02T19:52:00.000Z
# 5       Non-Residential Burglary  2017-01-03T02:47:00.000Z
# 6                          Theft  2017-01-02T19:29:00.000Z
# 7              Weapons Violation  2017-01-02T19:15:00.000Z
# 8                        Robbery  2017-01-03T18:46:00.000Z
# 9                        Robbery  2017-01-03T20:10:00.000Z
# 10     Miscellaneous Sex Offense  2017-01-03T20:54:00.000Z
# 11            Drug Investigation  2017-01-03T09:19:00.000Z
# 12            Drug Investigation  2017-01-04T00:17:00.000Z
# 13   Intoxicated/Impaired Driver  2017-01-04T16:36:00.000Z
# 14                       Robbery  2017-01-05T00:45:00.000Z
# ...

# %%
# 2016
y2016 = incidentRep.loc[0:500, ['IncidentType', 'IncidentDate', 'Details']]
y2016

currRow = 0 

for i, row in incidentRep.iterrows():
    newstr = row["IncidentDate"][:4]
    if newstr == "2016":
        y2016.loc[currRow, "IncidentType"] = row["IncidentType"]
        y2016.loc[currRow, "IncidentDate"] = row["IncidentDate"]
        y2016.loc[currRow, "Details"] = row["Details"]
        currRow = currRow + 1
        
y2016
# Out:
#                     IncidentType              IncidentDate  \
# 0               Traffic Incident  2016-01-01T00:52:00.000Z
# 1              Weapons Violation  2016-01-01T06:30:00.000Z
# 2              Weapons Violation  2016-01-02T09:20:00.000Z
# 3                          Fraud  2016-01-02T17:18:00.000Z
# 4               Traffic Incident  2016-01-02T17:30:00.000Z
# 5                        Robbery  2016-01-02T20:13:00.000Z
# 6           Residential Burglary  2016-01-02T21:30:00.000Z
# 7              Weapons Violation  2016-01-01T06:34:00.000Z
# 8              Weapons Violation  2016-01-03T20:40:00.000Z
# 9              Weapons Violation  2016-01-03T19:11:00.000Z
# 10                       Battery  2016-01-01T19:25:00.000Z
# 11                       Battery  2016-01-01T04:09:00.000Z
# 12             Weapons Violation  2016-01-02T17:54:00.000Z
# 13                         Theft  2016-01-04T19:30:00.000Z
# 14                       Robbery  2016-01-05T20:30:00.000Z
# ...

# %%
# 2015
y2015 = incidentRep.loc[0:500, ['IncidentType', 'IncidentDate', 'Details']]
y2015

currRow = 0 

for i, row in incidentRep.iterrows():
    newstr = row["IncidentDate"][:4]
    if newstr == "2015":
        y2015.loc[currRow, "IncidentType"] = row["IncidentType"]
        y2015.loc[currRow, "IncidentDate"] = row["IncidentDate"]
        y2015.loc[currRow, "Details"] = row["Details"]
        currRow = currRow + 1
        
y2015
# Out:
#                     IncidentType              IncidentDate  \
# 0                    Disturbance  2015-01-01T00:55:00.000Z
# 1              Suspicious Person  2015-01-01T12:35:00.000Z
# 2                        Robbery  2015-01-02T19:56:00.000Z
# 3                        Robbery  2015-01-03T18:24:00.000Z
# 4                    Disturbance  2015-01-04T01:29:00.000Z
# 5                        Battery  2015-01-05T22:25:00.000Z
# 6               Traffic Incident  2015-01-06T15:55:00.000Z
# 7                        Battery  2015-01-07T10:30:00.000Z
# 8                Murder/Homicide  2015-01-10T00:45:00.000Z
# 9                        Robbery  2015-01-11T00:48:00.000Z
# 10              Traffic Incident  2015-01-10T03:00:00.000Z
# 11                       Robbery  2015-01-11T22:20:00.000Z
# 12                   Disturbance  2015-01-12T11:57:00.000Z
# 13                         Theft  2015-01-10T21:35:00.000Z
# 14                         Theft  2015-01-06T17:35:00.000Z
# ...

# %%
# 2014
y2014 = incidentRep.loc[0:500, ['IncidentType', 'IncidentDate', 'Details']]
y2014

currRow = 0 

for i, row in incidentRep.iterrows():
    newstr = row["IncidentDate"][:4]
    if newstr == "2014":
        y2014.loc[currRow, "IncidentType"] = row["IncidentType"]
        y2014.loc[currRow, "IncidentDate"] = row["IncidentDate"]
        y2014.loc[currRow, "Details"] = row["Details"]
        currRow = currRow + 1
        
y2014
# Out:
#                     IncidentType              IncidentDate  \
# 0    Intoxicated/Impaired Driver  2014-06-08T17:40:00.000Z
# 1              Weapons Violation  2014-06-08T17:38:00.000Z
# 2                          Theft  2014-06-08T08:27:00.000Z
# 3                          Fraud  2014-06-05T16:30:00.000Z
# 4                Unwanted Person  2014-06-09T11:00:00.000Z
# 5              Weapons Violation  2014-06-11T01:54:00.000Z
# 6              Weapons Violation  2014-06-11T03:13:00.000Z
# 7                          Theft  2014-06-12T03:04:00.000Z
# 8                  Missing Adult  2014-06-11T20:13:00.000Z
# 9                          Fraud  2014-05-20T18:41:00.000Z
# 10                       Battery  2014-06-13T02:05:00.000Z
# 11                       Robbery  2014-06-13T02:15:00.000Z
# 12              Traffic Incident  2014-06-13T06:54:00.000Z
# 13                         Theft  2014-06-08T14:00:00.000Z
# 14          Residential Burglary  2014-06-13T07:21:00.000Z
# ...

# %%
# 2013
y2013 = incidentRep.loc[0:500, ['IncidentType', 'IncidentDate', 'Details']]
y2013

currRow = 0 

for i, row in incidentRep.iterrows():
    newstr = row["IncidentDate"][:4]
    if newstr == "2013":
        y2013.loc[currRow, "IncidentType"] = row["IncidentType"]
        y2013.loc[currRow, "IncidentDate"] = row["IncidentDate"]
        y2013.loc[currRow, "Details"] = row["Details"]
        currRow = currRow + 1
        
y2013
# Out:
#                      IncidentType              IncidentDate  \
# 0              Fire Investigation  2013-01-13T18:37:00.000Z
# 1                 Arrested Person  2013-01-01T05:00:00.000Z
# 2             Fight (In Progress)  2013-01-02T17:35:00.000Z
# 3               Weapons Violation  2013-01-01T20:04:00.000Z
# 4                 Arrested Person  2013-01-01T00:25:00.000Z
# 5             Fight (In Progress)  2013-01-01T02:07:00.000Z
# 6                     Disturbance  2013-01-01T04:06:00.000Z
# 7              Intoxicated Driver  2013-01-01T02:45:00.000Z
# 8                           Fraud  2013-01-01T01:40:00.000Z
# 9                         Robbery  2013-01-06T03:06:00.000Z
# 10                    Stolen Auto  2013-01-05T02:23:00.000Z
# 11                        Battery  2013-01-04T18:30:00.000Z
# 12               Traffic Incident  2013-01-07T15:00:00.000Z
# 13                        Battery  2013-01-05T15:10:00.000Z
# 14                          Theft  2013-01-07T14:00:00.000Z
# ...

# %%
# 2012
y2012 = incidentRep.loc[0:500, ['IncidentType', 'IncidentDate', 'Details']]
y2012

currRow = 0 

for i, row in incidentRep.iterrows():
    newstr = row["IncidentDate"][:4]
    if newstr == "2012":
        y2012.loc[currRow, "IncidentType"] = row["IncidentType"]
        y2012.loc[currRow, "IncidentDate"] = row["IncidentDate"]
        y2012.loc[currRow, "Details"] = row["Details"]
        currRow = currRow + 1
        
y2012
# Out:
#                     IncidentType              IncidentDate  \
# 0                        Robbery  2012-11-12T20:00:00.000Z
# 1              Weapons Violation  2012-01-01T02:14:00.000Z
# 2              Weapons Violation  2012-01-01T03:44:00.000Z
# 3              Weapons Violation  2012-01-01T01:35:00.000Z
# 4           Residential Burglary  2012-01-01T01:31:00.000Z
# 5                Arrested Person  2012-01-03T22:40:00.000Z
# 6       Animal Complaint - Stray  2012-01-04T07:47:00.000Z
# 7                Arrested Person  2012-01-01T22:05:00.000Z
# 8             Intoxicated Driver  2012-01-01T22:19:00.000Z
# 9                Arrested Person  2012-01-01T02:15:00.000Z
# 10           Fight (In Progress)  2012-01-01T02:45:00.000Z
# 11               Arrested Person  2012-01-01T03:29:00.000Z
# 12           Fight (In Progress)  2012-01-01T05:20:00.000Z
# 13             Weapons Violation  2012-01-05T14:57:00.000Z
# 14               Arrested Person  2012-01-02T19:20:00.000Z
# ...

# %%
# 2011
y2011 = incidentRep.loc[0:500, ['IncidentType', 'IncidentDate', 'Details']]
y2011

currRow = 0 

for i, row in incidentRep.iterrows():
    newstr = row["IncidentDate"][:4]
    if newstr == "2011":
        y2011.loc[currRow, "IncidentType"] = row["IncidentType"]
        y2011.loc[currRow, "IncidentDate"] = row["IncidentDate"]
        y2011.loc[currRow, "Details"] = row["Details"]
        currRow = currRow + 1
        
y2011
# Out:
#                   IncidentType              IncidentDate  \
# 0            Weapons Violation  2011-01-03T02:43:00.000Z
# 1           Intoxicated Driver  2011-01-02T22:35:00.000Z
# 2                      Robbery  2011-01-04T00:09:00.000Z
# 3        Enticement/Kidnapping  2011-01-04T08:45:00.000Z
# 4                      Robbery  2011-01-04T12:40:00.000Z
# 5            Weapons Violation  2011-01-05T23:02:00.000Z
# 6              Arrested Person  2011-01-05T18:46:00.000Z
# 7           Drug Investigation  2011-01-05T18:55:00.000Z
# 8           Fire Investigation  2011-01-06T13:24:00.000Z
# 9                      Robbery  2011-01-07T00:00:00.000Z
# 10                 Disturbance  2011-01-08T01:38:00.000Z
# 11                     Robbery  2011-01-10T02:21:00.000Z
# 12             Arrested Person  2011-01-10T05:02:00.000Z
# 13         Fight (In Progress)  2011-01-09T02:26:00.000Z
# 14         Death Investigation  2011-01-08T07:46:00.000Z
# ...

# %%
# 2010
y2010 = incidentRep.loc[0:500, ['IncidentType', 'IncidentDate', 'Details']]
y2010

currRow = 0 

for i, row in incidentRep.iterrows():
    newstr = row["IncidentDate"][:4]
    if newstr == "2010":
        y2010.loc[currRow, "IncidentType"] = row["IncidentType"]
        y2010.loc[currRow, "IncidentDate"] = row["IncidentDate"]
        y2010.loc[currRow, "Details"] = row["Details"]
        currRow = currRow + 1
        
y2010
# Out:
#                   IncidentType              IncidentDate  \
# 0            Weapons Violation  2010-01-01T00:00:00.000Z
# 1          Death Investigation  2010-01-01T14:21:00.000Z
# 2                      Robbery  2010-01-01T01:55:00.000Z
# 3                      Robbery  2010-01-01T21:36:00.000Z
# 4                  Stolen Auto  2010-01-04T19:28:00.000Z
# 5              Arrested Person  2010-01-04T16:40:00.000Z
# 6            Weapons Violation  2010-01-04T22:42:00.000Z
# 7              Theft From Auto  2010-01-02T15:40:00.000Z
# 8                      Robbery  2010-01-06T17:54:00.000Z
# 9              Arrested Person  2010-01-07T03:00:00.000Z
# 10                     Battery  2010-01-06T07:04:00.000Z
# 11                     Battery  2010-01-06T00:33:00.000Z
# 12                     Robbery  2010-01-07T18:08:00.000Z
# 13                     Battery  2010-01-07T01:32:00.000Z
# 14                     Robbery  2010-01-07T21:17:00.000Z
# ...

# %%
# 2009
y2009 = incidentRep.loc[0:500, ['IncidentType', 'IncidentDate', 'Details']]
y2009

currRow = 0 

for i, row in incidentRep.iterrows():
    newstr = row["IncidentDate"][:4]
    if newstr == "2009":
        y2009.loc[currRow, "IncidentType"] = row["IncidentType"]
        y2009.loc[currRow, "IncidentDate"] = row["IncidentDate"]
        y2009.loc[currRow, "Details"] = row["Details"]
        currRow = currRow + 1
        
y2009
# Out:
#               IncidentType              IncidentDate  \
# 0                  Robbery  2009-01-01T01:00:00.000Z
# 1          Arrested Person  2009-01-02T12:01:00.000Z
# 2          Unwanted Person  2009-01-01T06:29:00.000Z
# 3                  Robbery  2009-01-03T05:21:00.000Z
# 4                  Robbery  2009-01-05T03:36:00.000Z
# 5        Suspicious Person  2009-01-01T15:11:00.000Z
# 6          Arrested Person  2009-01-04T02:06:00.000Z
# 7        Weapons Violation  2009-01-05T21:29:00.000Z
# 8        Suspicious Person  2009-01-03T12:45:00.000Z
# 9                  Robbery  2009-01-01T05:52:00.000Z
# 10       Weapons Violation  2009-01-01T00:05:00.000Z
# 11       Weapons Violation  2009-01-01T15:43:00.000Z
# 12        Missing Juvenile  2009-01-06T16:45:00.000Z
# 13                   Fraud  2009-01-05T12:21:00.000Z
# 14      Intoxicated Driver  2009-01-07T02:02:00.000Z
# 15                   Fraud  2009-01-06T11:29:00.000Z
# 16                   Theft  2009-01-06T16:08:00.000Z
# ...

# %%
# 2008
y2008 = incidentRep.loc[0:500, ['IncidentType', 'IncidentDate', 'Details']]
y2008

currRow = 0 

for i, row in incidentRep.iterrows():
    newstr = row["IncidentDate"][:4]
    if newstr == "2008":
        y2008.loc[currRow, "IncidentType"] = row["IncidentType"]
        y2008.loc[currRow, "IncidentDate"] = row["IncidentDate"]
        y2008.loc[currRow, "Details"] = row["Details"]
        currRow = currRow + 1
        
y2008
# Out:
#                     IncidentType              IncidentDate  \
# 0              Weapons Violation  2008-01-01T06:21:00.000Z
# 1                    Stolen Auto  2008-01-02T18:32:00.000Z
# 2                        Robbery  2008-01-03T20:34:00.000Z
# 3                 Sexual Assault  2008-01-03T17:56:00.000Z
# 4             Drug Investigation  2008-01-02T17:32:00.000Z
# 5             Intoxicated Driver  2008-01-07T20:43:00.000Z
# 6                Theft From Auto  2008-01-07T19:31:00.000Z
# 7                        Robbery  2008-01-08T11:17:00.000Z
# 8                 Sexual Assault  2008-01-08T09:27:00.000Z
# 9          Enticement/Kidnapping  2008-01-08T09:34:00.000Z
# 10                       Robbery  2008-01-09T07:21:00.000Z
# 11                         Theft  2008-01-09T13:58:00.000Z
# 12      Non-Residential Burglary  2008-01-11T01:37:00.000Z
# 13                       Robbery  2008-01-09T19:34:00.000Z
# 14                 Missing Adult  2008-01-11T06:34:00.000Z
# ...

# %%
# 2017 WV only
y2017wv = y2017.loc[0:10, ['IncidentType', 'IncidentDate', 'Details']]
y2017wv

currRow = 0

for i, row in y2017.iterrows():
    newstr = row["IncidentDate"][:4]
    currInc = row['IncidentType']
    
    if currInc == "Weapons Violation":
        if newstr == "2017":
            y2017wv.loc[currRow, "IncidentType"] = row["IncidentType"]
            y2017wv.loc[currRow, "IncidentDate"] = row["IncidentDate"]
            y2017wv.loc[currRow, "Details"] = row["Details"]
            currRow = currRow + 1
            
y2017wv
# Out:
#           IncidentType              IncidentDate  \
# 0    Weapons Violation  2017-01-01T02:40:00.000Z
# 1    Weapons Violation  2017-01-01T19:13:00.000Z
# 2    Weapons Violation  2017-01-02T19:52:00.000Z
# 3    Weapons Violation  2017-01-02T19:15:00.000Z
# 4    Weapons Violation  2017-01-08T05:07:00.000Z
# 5    Weapons Violation  2017-01-09T02:37:00.000Z
# 6    Weapons Violation  2017-01-08T19:43:00.000Z
# 7    Weapons Violation  2017-01-13T08:46:00.000Z
# 8    Weapons Violation  2017-01-13T14:00:00.000Z
# 9    Weapons Violation  2017-01-14T19:40:00.000Z
# 10   Weapons Violation  2017-01-13T22:00:00.000Z
# 11   Weapons Violation  2017-01-12T05:30:00.000Z
# 12   Weapons Violation  2017-01-17T20:24:00.000Z
# 13   Weapons Violation  2017-01-18T23:46:00.000Z
# 14   Weapons Violation  2017-01-18T21:30:00.000Z
# 15   Weapons Violation  2017-01-22T02:53:00.000Z
# 16   Weapons Violation  2017-01-23T02:00:00.000Z
# 17   Weapons Violation  2017-01-22T12:42:00.000Z
# ...

# %%
# 2016 WV only
y2016wv = y2016.loc[0:10, ['IncidentType', 'IncidentDate', 'Details']]
y2016wv

currRow = 0

for i, row in y2016.iterrows():
    newstr = row["IncidentDate"][:4]
    currInc = row['IncidentType']
    
    if currInc == "Weapons Violation":
        if newstr == "2016":
            y2016wv.loc[currRow, "IncidentType"] = row["IncidentType"]
            y2016wv.loc[currRow, "IncidentDate"] = row["IncidentDate"]
            y2016wv.loc[currRow, "Details"] = row["Details"]
            currRow = currRow + 1
            
y2016wv
# Out:
#           IncidentType              IncidentDate  \
# 0    Weapons Violation  2016-01-01T06:30:00.000Z
# 1    Weapons Violation  2016-01-02T09:20:00.000Z
# 2    Weapons Violation  2016-01-01T06:34:00.000Z
# 3    Weapons Violation  2016-01-03T20:40:00.000Z
# 4    Weapons Violation  2016-01-03T19:11:00.000Z
# 5    Weapons Violation  2016-01-02T17:54:00.000Z
# 6    Weapons Violation  2016-01-08T00:01:00.000Z
# 7    Weapons Violation  2016-01-12T13:42:00.000Z
# 8    Weapons Violation  2016-01-19T23:32:00.000Z
# 9    Weapons Violation  2016-01-20T21:54:00.000Z
# 10   Weapons Violation  2016-01-20T12:40:00.000Z
# 11   Weapons Violation  2016-01-21T12:39:00.000Z
# 12   Weapons Violation  2016-01-24T10:20:00.000Z
# 13   Weapons Violation  2016-01-23T18:22:00.000Z
# 14   Weapons Violation  2016-01-23T17:46:00.000Z
# 15   Weapons Violation  2016-01-25T17:19:00.000Z
# 16   Weapons Violation  2016-02-01T23:49:00.000Z
# 17   Weapons Violation  2016-02-02T21:37:00.000Z
# ...

# %%
# 2015 WV only
y2015wv = y2015.loc[0:10, ['IncidentType', 'IncidentDate', 'Details']]
y2015wv

currRow = 0

for i, row in y2015.iterrows():
    newstr = row["IncidentDate"][:4]
    currInc = row['IncidentType']
    
    if currInc == "Weapons Violation":
        if newstr == "2015":
            y2015wv.loc[currRow, "IncidentType"] = row["IncidentType"]
            y2015wv.loc[currRow, "IncidentDate"] = row["IncidentDate"]
            y2015wv.loc[currRow, "Details"] = row["Details"]
            currRow = currRow + 1
            
y2015wv
# Out:
#           IncidentType              IncidentDate  \
# 0    Weapons Violation  2015-01-15T19:46:00.000Z
# 1    Weapons Violation  2015-01-18T06:00:00.000Z
# 2    Weapons Violation  2015-01-19T13:44:00.000Z
# 3    Weapons Violation  2015-01-23T16:00:00.000Z
# 4    Weapons Violation  2015-01-29T13:16:00.000Z
# 5    Weapons Violation  2015-01-31T02:11:00.000Z
# 6    Weapons Violation  2015-01-31T10:42:00.000Z
# 7    Weapons Violation  2015-01-31T00:03:00.000Z
# 8    Weapons Violation  2015-01-31T22:30:00.000Z
# 9    Weapons Violation  2015-02-06T21:34:00.000Z
# 10   Weapons Violation  2015-02-12T21:01:00.000Z
# 11   Weapons Violation  2015-02-17T17:10:00.000Z
# 12   Weapons Violation  2015-02-20T13:00:00.000Z
# 13   Weapons Violation  2015-02-27T01:23:00.000Z
# 14   Weapons Violation  2015-02-28T17:37:00.000Z
# 15   Weapons Violation  2015-02-28T22:11:00.000Z
# 16   Weapons Violation  2015-03-01T16:04:00.000Z
# 17   Weapons Violation  2015-03-03T12:39:00.000Z
# ...

# %%
# 2014 WV only
y2014wv = y2014.loc[0:10, ['IncidentType', 'IncidentDate', 'Details']]
y2014wv

currRow = 0

for i, row in y2014.iterrows():
    newstr = row["IncidentDate"][:4]
    currInc = row['IncidentType']
    
    if currInc == "Weapons Violation":
        if newstr == "2014":
            y2014wv.loc[currRow, "IncidentType"] = row["IncidentType"]
            y2014wv.loc[currRow, "IncidentDate"] = row["IncidentDate"]
            y2014wv.loc[currRow, "Details"] = row["Details"]
            currRow = currRow + 1
            
y2014wv
# Out:
#           IncidentType              IncidentDate  \
# 0    Weapons Violation  2014-06-08T17:38:00.000Z
# 1    Weapons Violation  2014-06-11T01:54:00.000Z
# 2    Weapons Violation  2014-06-11T03:13:00.000Z
# 3    Weapons Violation  2014-06-18T20:25:00.000Z
# 4    Weapons Violation  2014-07-10T17:35:00.000Z
# 5    Weapons Violation  2014-07-16T23:31:00.000Z
# 6    Weapons Violation  2014-07-18T00:05:00.000Z
# 7    Weapons Violation  2014-07-18T14:07:00.000Z
# 8    Weapons Violation  2014-07-24T17:38:00.000Z
# 9    Weapons Violation  2014-07-24T22:14:00.000Z
# 10   Weapons Violation  2014-07-27T02:08:00.000Z
# 11   Weapons Violation  2014-07-30T00:01:00.000Z
# 12   Weapons Violation  2014-08-06T01:41:00.000Z
# 13   Weapons Violation  2014-08-09T03:39:00.000Z
# 14   Weapons Violation  2014-07-31T13:28:00.000Z
# 15   Weapons Violation  2014-08-17T21:23:00.000Z
# 16   Weapons Violation  2014-08-16T03:25:00.000Z
# 17   Weapons Violation  2014-08-20T00:57:00.000Z
# ...

# %%
# 2013 WV only
y2013wv = y2013.loc[0:10, ['IncidentType', 'IncidentDate', 'Details']]
y2013wv

currRow = 0

for i, row in y2013.iterrows():
    newstr = row["IncidentDate"][:4]
    currInc = row['IncidentType']
    
    if currInc == "Weapons Violation":
        if newstr == "2013":
            y2013wv.loc[currRow, "IncidentType"] = row["IncidentType"]
            y2013wv.loc[currRow, "IncidentDate"] = row["IncidentDate"]
            y2013wv.loc[currRow, "Details"] = row["Details"]
            currRow = currRow + 1
            
y2013wv
# Out:
#           IncidentType              IncidentDate  \
# 0    Weapons Violation  2013-01-01T20:04:00.000Z
# 1    Weapons Violation  2013-01-07T15:42:00.000Z
# 2    Weapons Violation  2013-01-09T03:46:00.000Z
# 3    Weapons Violation  2013-01-10T09:15:00.000Z
# 4    Weapons Violation  2013-01-13T08:10:00.000Z
# 5    Weapons Violation  2013-01-16T13:30:00.000Z
# 6    Weapons Violation  2013-01-16T20:05:00.000Z
# 7    Weapons Violation  2013-01-20T13:25:00.000Z
# 8    Weapons Violation  2013-01-20T14:19:00.000Z
# 9    Weapons Violation  2013-01-28T00:58:00.000Z
# 10   Weapons Violation  2013-01-28T23:43:00.000Z
# 11   Weapons Violation  2013-01-28T22:19:00.000Z
# 12   Weapons Violation  2013-02-04T14:50:00.000Z
# 13   Weapons Violation  2013-02-02T20:00:00.000Z
# 14   Weapons Violation  2013-02-09T11:12:00.000Z
# 15   Weapons Violation  2013-02-09T00:49:00.000Z
# 16   Weapons Violation  2013-02-12T01:06:00.000Z
# 17   Weapons Violation  2013-02-20T23:07:00.000Z
# ...

# %%
# 2012 WV only
y2012wv = y2012.loc[0:10, ['IncidentType', 'IncidentDate', 'Details']]
y2012wv

currRow = 0

for i, row in y2012.iterrows():
    newstr = row["IncidentDate"][:4]
    currInc = row['IncidentType']
    
    if currInc == "Weapons Violation":
        if newstr == "2012":
            y2012wv.loc[currRow, "IncidentType"] = row["IncidentType"]
            y2012wv.loc[currRow, "IncidentDate"] = row["IncidentDate"]
            y2012wv.loc[currRow, "Details"] = row["Details"]
            currRow = currRow + 1
            
y2012wv
# Out:
#           IncidentType              IncidentDate  \
# 0    Weapons Violation  2012-01-01T02:14:00.000Z
# 1    Weapons Violation  2012-01-01T03:44:00.000Z
# 2    Weapons Violation  2012-01-01T01:35:00.000Z
# 3    Weapons Violation  2012-01-05T14:57:00.000Z
# 4    Weapons Violation  2012-01-03T22:53:00.000Z
# 5    Weapons Violation  2012-01-09T01:28:00.000Z
# 6    Weapons Violation  2012-01-12T00:25:00.000Z
# 7    Weapons Violation  2012-01-17T01:04:00.000Z
# 8    Weapons Violation  2012-01-15T02:22:00.000Z
# 9    Weapons Violation  2012-01-19T23:35:00.000Z
# 10   Weapons Violation  2012-01-25T22:55:00.000Z
# 11   Weapons Violation  2012-01-26T22:01:00.000Z
# 12   Weapons Violation  2012-01-27T23:22:00.000Z
# 13   Weapons Violation  2012-02-01T21:50:00.000Z
# 14   Weapons Violation  2012-02-18T20:27:00.000Z
# 15   Weapons Violation  2012-02-17T11:34:00.000Z
# 16   Weapons Violation  2012-02-24T23:45:00.000Z
# 17   Weapons Violation  2012-02-26T01:45:00.000Z
# ...

# %%
# 2011 WV only
y2011wv = y2011.loc[0:10, ['IncidentType', 'IncidentDate', 'Details']]
y2011wv

currRow = 0

for i, row in y2011.iterrows():
    newstr = row["IncidentDate"][:4]
    currInc = row['IncidentType']
    
    if currInc == "Weapons Violation":
        if newstr == "2011":
            y2011wv.loc[currRow, "IncidentType"] = row["IncidentType"]
            y2011wv.loc[currRow, "IncidentDate"] = row["IncidentDate"]
            y2011wv.loc[currRow, "Details"] = row["Details"]
            currRow = currRow + 1
            
y2011wv
# Out:
#           IncidentType              IncidentDate  \
# 0    Weapons Violation  2011-01-03T02:43:00.000Z
# 1    Weapons Violation  2011-01-05T23:02:00.000Z
# 2    Weapons Violation  2011-01-12T17:09:00.000Z
# 3    Weapons Violation  2011-01-13T05:58:00.000Z
# 4    Weapons Violation  2011-01-14T12:07:00.000Z
# 5    Weapons Violation  2011-01-18T02:49:00.000Z
# 6    Weapons Violation  2011-01-28T22:04:00.000Z
# 7    Weapons Violation  2011-01-29T22:36:00.000Z
# 8    Weapons Violation  2011-02-11T20:57:00.000Z
# 9    Weapons Violation  2011-02-21T22:01:00.000Z
# 10   Weapons Violation  2011-03-03T19:47:00.000Z
# 11   Weapons Violation  2011-03-04T08:23:00.000Z
# 12   Weapons Violation  2011-03-10T03:03:00.000Z
# 13   Weapons Violation  2011-03-13T03:27:00.000Z
# 14   Weapons Violation  2011-03-16T17:17:00.000Z
# 15   Weapons Violation  2011-03-27T02:52:00.000Z
# 16   Weapons Violation  2011-03-26T21:48:00.000Z
# 17   Weapons Violation  2011-03-29T15:38:00.000Z
# ...

# %%
# 2010 WV only
y2010wv = y2010.loc[0:10, ['IncidentType', 'IncidentDate', 'Details']]
y2010wv

currRow = 0

for i, row in y2010.iterrows():
    newstr = row["IncidentDate"][:4]
    currInc = row['IncidentType']
    
    if currInc == "Weapons Violation":
        if newstr == "2010":
            y2010wv.loc[currRow, "IncidentType"] = row["IncidentType"]
            y2010wv.loc[currRow, "IncidentDate"] = row["IncidentDate"]
            y2010wv.loc[currRow, "Details"] = row["Details"]
            currRow = currRow + 1
            
y2010wv
# Out:
#           IncidentType              IncidentDate  \
# 0    Weapons Violation  2010-01-01T00:00:00.000Z
# 1    Weapons Violation  2010-01-04T22:42:00.000Z
# 2    Weapons Violation  2010-01-10T00:23:00.000Z
# 3    Weapons Violation  2010-01-10T00:23:00.000Z
# 4    Weapons Violation  2010-01-12T01:41:00.000Z
# 5    Weapons Violation  2010-01-08T15:04:00.000Z
# 6    Weapons Violation  2010-01-22T02:00:00.000Z
# 7    Weapons Violation  2010-01-31T02:13:00.000Z
# 8    Weapons Violation  2010-02-05T16:04:00.000Z
# 9    Weapons Violation  2010-02-12T21:35:00.000Z
# 10   Weapons Violation  2010-02-19T23:14:00.000Z
# 11   Weapons Violation  2010-02-24T00:03:00.000Z
# 12   Weapons Violation  2010-02-25T11:24:00.000Z
# 13   Weapons Violation  2010-03-03T01:30:00.000Z
# 14   Weapons Violation  2010-03-05T08:14:00.000Z
# 15   Weapons Violation  2010-03-06T02:40:00.000Z
# 16   Weapons Violation  2010-03-09T21:48:00.000Z
# 17   Weapons Violation  2010-03-10T21:14:00.000Z
# ...

# %%
# 2009 WV only
y2009wv = y2009.loc[0:10, ['IncidentType', 'IncidentDate', 'Details']]
y2009wv

currRow = 0

for i, row in y2009.iterrows():
    newstr = row["IncidentDate"][:4]
    currInc = row['IncidentType']
    
    if currInc == "Weapons Violation":
        if newstr == "2009":
            y2009wv.loc[currRow, "IncidentType"] = row["IncidentType"]
            y2009wv.loc[currRow, "IncidentDate"] = row["IncidentDate"]
            y2009wv.loc[currRow, "Details"] = row["Details"]
            currRow = currRow + 1
            
y2009wv
# Out:
#          IncidentType              IncidentDate  \
# 0   Weapons Violation  2009-01-05T21:29:00.000Z
# 1   Weapons Violation  2009-01-01T00:05:00.000Z
# 2   Weapons Violation  2009-01-01T15:43:00.000Z
# 3   Weapons Violation  2009-01-16T16:43:00.000Z
# 4   Weapons Violation  2009-01-28T22:33:00.000Z
# 5   Weapons Violation  2009-01-29T00:03:00.000Z
# 6   Weapons Violation  2009-01-31T16:49:00.000Z
# 7   Weapons Violation  2009-02-06T15:57:00.000Z
# 8   Weapons Violation  2009-02-18T12:22:00.000Z
# 9   Weapons Violation  2009-02-19T17:23:00.000Z
# 10  Weapons Violation  2009-02-21T04:10:00.000Z
# 11  Weapons Violation  2009-02-22T11:08:00.000Z
# 12  Weapons Violation  2009-03-02T23:15:00.000Z
# 13  Weapons Violation  2009-03-10T19:43:00.000Z
# 14  Weapons Violation  2009-03-12T09:15:00.000Z
# 15  Weapons Violation  2009-03-29T15:48:00.000Z
# 16  Weapons Violation  2009-03-26T18:46:00.000Z
# 17  Weapons Violation  2009-04-02T14:08:00.000Z
# ...

# %%
# 2008 WV only
y2008wv = y2008.loc[0:10, ['IncidentType', 'IncidentDate', 'Details']]
y2008wv

currRow = 0

for i, row in y2008.iterrows():
    newstr = row["IncidentDate"][:4]
    currInc = row['IncidentType']
    
    if currInc == "Weapons Violation":
        if newstr == "2008":
            y2008wv.loc[currRow, "IncidentType"] = row["IncidentType"]
            y2008wv.loc[currRow, "IncidentDate"] = row["IncidentDate"]
            y2008wv.loc[currRow, "Details"] = row["Details"]
            currRow = currRow + 1
            
y2008wv
# Out:
#          IncidentType              IncidentDate  \
# 0   Weapons Violation  2008-01-01T06:21:00.000Z
# 1   Weapons Violation  2008-01-19T00:20:00.000Z
# 2   Weapons Violation  2008-01-19T02:23:00.000Z
# 3   Weapons Violation  2008-01-24T23:49:00.000Z
# 4   Weapons Violation  2008-01-30T01:05:00.000Z
# 5   Weapons Violation  2008-02-02T02:05:00.000Z
# 6   Weapons Violation  2008-02-09T02:12:00.000Z
# 7   Weapons Violation  2008-02-24T19:00:00.000Z
# 8   Weapons Violation  2008-02-24T22:39:00.000Z
# 9   Weapons Violation  2008-04-20T21:52:00.000Z
# 10  Weapons Violation  2008-04-24T03:17:00.000Z
# 11  Weapons Violation  2008-04-27T00:44:00.000Z
# 12  Weapons Violation  2008-05-07T21:37:00.000Z
# 13  Weapons Violation  2008-05-22T00:35:00.000Z
# 14  Weapons Violation  2008-05-29T23:06:00.000Z
# 15  Weapons Violation  2008-06-01T02:00:00.000Z
# 16  Weapons Violation  2008-05-31T16:18:00.000Z
# 17  Weapons Violation  2008-06-02T20:32:00.000Z
# ...

# %%
knife = 0
gun = 0

for i, row in y2017wv.iterrows():
    #print(row["Details"])
    #print("\n")
    
    if "gun" in row["Details"]:
        gun += 1
        y2017wv.loc[i, "WeapType"] = "gun"
        
    elif "shots" in row["Details"]:
        gun += 1
        y2017wv.loc[i, "WeapType"] = "gun"
        
    elif "shot" in row["Details"]:
        gun += 1
        y2017wv.loc[i, "WeapType"] = "gun"
        
    elif "fired" in row["Details"]:
        gun += 1
        y2017wv.loc[i, "WeapType"] = "gun"
        
    elif "shooting" in row["Details"]:
        gun += 1
        y2017wv.loc[i, "WeapType"] = "gun"
        
    elif "knife" in row["Details"]:
        knife += 1
        y2017wv.loc[i, "WeapType"] = "knife"
        
    elif "stabbed" in row["Details"]:
        knife += 1
        y2017wv.loc[i, "WeapType"] = "knife"
        
    elif "stab" in row["Details"]:
        knife += 1
        y2017wv.loc[i, "WeapType"] = "knife"
        
    elif "cut" in row["Details"]:
        knife += 1
        y2017wv.loc[i, "WeapType"] = "knife"
        
    else:
        print(row["Details"])
        print("\n")
        
print(knife)
print(gun)

VioType.loc['Gun', 'Amount for 2017'] = gun
VioType.loc['Knife', 'Amount for 2017'] = knife
# Out:
# Officers were dispatched to an apartment building in the 2200 block of Cypress Way reference an unconscious man.&nbsp; Upon arrival to the scene the man was already in his apartment.&nbsp; Officers heard sounds from inside the apartment that indicated that the subject needed his welfare checked.&nbsp; MFD and MPD made entry and were met with the man pointing a fiream toward them.&nbsp;&nbsp;Officers successfully de-escalated the situation and took the man into custody without incident.&nbsp; There were&nbsp;no injuries.
#
#
# City of Madison Police are currently investigating a weapons violation that occurred in the 6700 Block of Jacobs Way shortly after 7:30PM.&nbsp; At this point several shell casing have been found in the roadway, and several buildings have sustained property damage.&nbsp; There are no injuries that have been reported at this time due to this incident.
#
#
# ...

# %%
knife = 0
gun = 0

for i, row in y2016wv.iterrows():
    #print(row["Details"])
    #print("\n")
    
    if "gun" in row["Details"]:
        gun += 1
        y2016wv.loc[i, "WeapType"] = "gun"
        
    elif "shots" in row["Details"]:
        gun += 1
        y2016wv.loc[i, "WeapType"] = "gun"
        
    elif "shot" in row["Details"]:
        gun += 1
        y2016wv.loc[i, "WeapType"] = "gun"
        
    elif "fired" in row["Details"]:
        gun += 1
        y2016wv.loc[i, "WeapType"] = "gun"
        
    elif "shooting" in row["Details"]:
        gun += 1
        y2016wv.loc[i, "WeapType"] = "gun"
        
    elif "knife" in row["Details"]:
        knife += 1
        y2016wv.loc[i, "WeapType"] = "knife"
        
    elif "stabbed" in row["Details"]:
        knife += 1
        y2016wv.loc[i, "WeapType"] = "knife"
        
    elif "stab" in row["Details"]:
        knife += 1
        y2016wv.loc[i, "WeapType"] = "knife"
        
    elif "cut" in row["Details"]:
        knife += 1
        y2016wv.loc[i, "WeapType"] = "knife"
        
    else:
        print(row["Details"])
        print("\n")
        
print(knife)
print(gun)

VioType.loc['Gun', 'Amount for 2016'] = gun
VioType.loc['Knife', 'Amount for 2016'] = knife

VioType
# Out:
# Madison’s Gang Unit is seeking citizen help in locating a wanted suspect. &nbsp;Xavier D. Davis, age 20, no permanent address, is a suspected gang member. He should be considered armed and dangerous as he has a history of unlawfully carrying concealed weapons.<br />
# &nbsp;<br />
# The MPD has probable cause to arrest Davis for resisting. He is also wanted on bench warrants for failure to appear in court on several charges:<br />
# &nbsp;
# <ul>
# 	<li>Adjudicated Delinquent in Possession of a Firearm</li>
# 	<li>Possession with Intent to Deliver Heroin</li>
# 	<li>Felony Bail Jumping</li>
# 	<li>Resisting a Peace Officer</li>
# </ul>
# Anyone with information on the suspect’s whereabouts is urged to contact Madison Area Crime Stoppers at 266-6014. Anyone seeing him should call 911.<br />
# &nbsp;
#
#
# ...

# %%
knife = 0
gun = 0

for i, row in y2015wv.iterrows():
    #print(row["Details"])
    #print("\n")
    
    if "gun" in row["Details"]:
        gun += 1
        y2015wv.loc[i, "WeapType"] = "gun"
        
    elif "shots" in row["Details"]:
        gun += 1
        y2015wv.loc[i, "WeapType"] = "gun"
        
    elif "shot" in row["Details"]:
        gun += 1
        y2015wv.loc[i, "WeapType"] = "gun"
        
    elif "fired" in row["Details"]:
        gun += 1
        y2015wv.loc[i, "WeapType"] = "gun"
        
    elif "shooting" in row["Details"]:
        gun += 1
        y2015wv.loc[i, "WeapType"] = "gun"
        
    elif "knife" in row["Details"]:
        knife += 1
        y2015wv.loc[i, "WeapType"] = "knife"
        
    elif "stabbed" in row["Details"]:
        knife += 1
        y2015wv.loc[i, "WeapType"] = "knife"
        
    elif "stab" in row["Details"]:
        knife += 1
        y2015wv.loc[i, "WeapType"] = "knife"
        
    elif "cut" in row["Details"]:
        knife += 1
        y2015wv.loc[i, "WeapType"] = "knife"
        
    else:
        print(row["Details"])
        print("\n")
        
print(knife)
print(gun)

VioType.loc['Gun', 'Amount for 2015'] = gun
VioType.loc['Knife', 'Amount for 2015'] = knife

VioType
# Out:
# Officers were sent to the West Transfer Point reference a possible weapons offense.&nbsp; Investigation disclosed that group individuals had an altercation in which an anonymous witness reported one person displaying a firearm.&nbsp; Officers at the scene failed to locate any weapons and it appears as though the parties involved knew each other.&nbsp; Investigation is continuing.
#
#
# Officers responded to the 1300 block of Loreen Dr, for a report of a person breaking windows with a sword.&nbsp; Officers arrived on scene in just over a minute after dispatch and observed a man wielding a machete.&nbsp;<br />
# <br />
# Upon seeing the police, the man dropped the machete and fled on foot.&nbsp; Officers pursued the suspect and were able to take him into custody after a short struggle.&nbsp; Prior to being transported to the jail, the suspect was taken to a hospital for a medical clearance.&nbsp; One officer received minor injuries during the struggle.
#
#
# ...

# %%
knife = 0
gun = 0

for i, row in y2014wv.iterrows():
    #print(row["Details"])
    #print("\n")
    
    if "gun" in row["Details"]:
        gun += 1
        y2014wv.loc[i, "WeapType"] = "gun"
        
    elif "shots" in row["Details"]:
        gun += 1
        y2014wv.loc[i, "WeapType"] = "gun"
        
    elif "shot" in row["Details"]:
        gun += 1
        y2014wv.loc[i, "WeapType"] = "gun"
        
    elif "fired" in row["Details"]:
        gun += 1
        y2014wv.loc[i, "WeapType"] = "gun"
        
    elif "shooting" in row["Details"]:
        gun += 1
        y2014wv.loc[i, "WeapType"] = "gun"
        
    elif "knife" in row["Details"]:
        knife += 1
        y2014wv.loc[i, "WeapType"] = "knife"
        
    elif "stabbed" in row["Details"]:
        knife += 1
        y2014wv.loc[i, "WeapType"] = "knife"
        
    elif "stab" in row["Details"]:
        knife += 1
        y2014wv.loc[i, "WeapType"] = "knife"
        
    elif "cut" in row["Details"]:
        knife += 1
        y2014wv.loc[i, "WeapType"] = "knife"
        
    else:
        print(row["Details"])
        print("\n")
        
print(knife)
print(gun)

VioType.loc['Gun', 'Amount for 2014'] = gun
VioType.loc['Knife', 'Amount for 2014'] = knife

VioType
# Out:
#  Downtown officers seized a 24" sword from beneath the sleeping bag of a man who was dozing in the 500 block of N. Frances St. Tuesday night. The MPD had awoken him because he had items plugged into a City of Madison power outlet. The 69-yer-old initially said the sword belonged to another slumbering man, but later acknowledged it was his.
#
#
# On 3/5/2014 at 10:34 p.m. Madison Police Officers responded to the 4500 block of Cottage Grove Rd for an apparent attempted robbery.  Officers learned that the victim was in the parking lot waiting to bring someone to work.  The male victim was approached by the suspect and was told to go into his apartment.  In doing so, the suspect also displayed a weapon to the victim.  The victim refused to go with the suspect's intentions and the suspect fled the area.  This remains an open investigation by the Madison Police Department.
#
#
# 21
# 86
#        Amount for 2018  Amount for 2017  Amount for 2016  Amount for 2015  \
# Type
# ...

# %%
knife = 0
gun = 0

for i, row in y2013wv.iterrows():
    #print(row["Details"])
    #print("\n")
    
    if "gun" in row["Details"]:
        gun += 1
        y2013wv.loc[i, "WeapType"] = "gun"
        
    elif "shots" in row["Details"]:
        gun += 1
        y2013wv.loc[i, "WeapType"] = "gun"
        
    elif "shot" in row["Details"]:
        gun += 1
        y2013wv.loc[i, "WeapType"] = "gun"
        
    elif "fired" in row["Details"]:
        gun += 1
        y2013wv.loc[i, "WeapType"] = "gun"
        
    elif "shooting" in row["Details"]:
        gun += 1
        y2013wv.loc[i, "WeapType"] = "gun"
        
    elif "knife" in row["Details"]:
        knife += 1
        y2013wv.loc[i, "WeapType"] = "knife"
        
    elif "stabbed" in row["Details"]:
        knife += 1
        y2013wv.loc[i, "WeapType"] = "knife"
        
    elif "stab" in row["Details"]:
        knife += 1
        y2013wv.loc[i, "WeapType"] = "knife"
        
    elif "cut" in row["Details"]:
        knife += 1
        y2013wv.loc[i, "WeapType"] = "knife"
        
    else:
        print(row["Details"])
        print("\n")
        
print(knife)
print(gun)

VioType.loc['Gun', 'Amount for 2013'] = gun
VioType.loc['Knife', 'Amount for 2013'] = knife

VioType
# Out:
# A 16-year old Sun Prairie resident was arrested outside of East Towne Mall Monday afternoon after he ran through the busy shopping center while trying to evade police. Officers had been called to the area after the suspect threatened a family member with a baseball bat following an argument in the mall’s parking lot.
#
#
# Miller turned himself in without incident to police.
#
# The MPD is seeking citizen help in locating a wanted man who is believed to be armed and possibly dangerous. There is probable cause to arrest Mr. David A. Miller, age 22, for 2nd Degree Reckless Endangering Safety following domestic related weapons incidents that took place inside his apartment in the 7400 block of Tree Lane. Mr. Miller was last seen at the apartment sometime Sunday afternoon. There is concern for Mr. Miller's welfare. Anyone seeing Mr. Miller should call 911. Mr. Miller is 5’10”, 150 pounds, with blonde hair and green eyes.
#
#
# ...

# %%
knife = 0
gun = 0

for i, row in y2012wv.iterrows():
    #print(row["Details"])
    #print("\n")
    
    if "gun" in row["Details"]:
        gun += 1
        y2012wv.loc[i, "WeapType"] = "gun"
        
    elif "shots" in row["Details"]:
        gun += 1
        y2012wv.loc[i, "WeapType"] = "gun"
        
    elif "shot" in row["Details"]:
        gun += 1
        y2012wv.loc[i, "WeapType"] = "gun"
        
    elif "fired" in row["Details"]:
        gun += 1
        y2012wv.loc[i, "WeapType"] = "gun"
        
    elif "shooting" in row["Details"]:
        gun += 1
        y2012wv.loc[i, "WeapType"] = "gun"
        
    elif "knife" in row["Details"]:
        knife += 1
        y2012wv.loc[i, "WeapType"] = "knife"
        
    elif "stabbed" in row["Details"]:
        knife += 1
        y2012wv.loc[i, "WeapType"] = "knife"
        
    elif "stab" in row["Details"]:
        knife += 1
        y2012wv.loc[i, "WeapType"] = "knife"
        
    elif "cut" in row["Details"]:
        knife += 1
        y2012wv.loc[i, "WeapType"] = "knife"
        
    else:
        print(row["Details"])
        print("\n")
        
print(knife)
print(gun)

VioType.loc['Gun', 'Amount for 2012'] = gun
VioType.loc['Knife', 'Amount for 2012'] = knife

VioType
# Out:
# An employee at the High Noon Saloon, 701 E. Washington Ave., heard a "pop" coming from the area of a men's restroom early this morning. Seconds later, the witness says many screaming people fled the dance floor and the area of the restroom. Investigators found a possible bullet hole inside the men's restroom. It appears the round exited inside a women's bathroom before lodging in the ceiling. Bouncers found a man bleeding from the face who said he had been pistol whipped, but another witness thought he had been struck with a bottle. The victim did not stick around. When officers arrived, they observed a large number of people yelling and swearing at each other while getting into cars and leaving the area.
#
#
# ...

# %%
knife = 0
gun = 0

for i, row in y2011wv.iterrows():
    #print(row["Details"])
    #print("\n")
    
    if "gun" in row["Details"]:
        gun += 1
        y2011wv.loc[i, "WeapType"] = "gun"
        
    elif "shots" in row["Details"]:
        gun += 1
        y2011wv.loc[i, "WeapType"] = "gun"
        
    elif "shot" in row["Details"]:
        gun += 1
        y2011wv.loc[i, "WeapType"] = "gun"
        
    elif "fired" in row["Details"]:
        gun += 1
        y2011wv.loc[i, "WeapType"] = "gun"
        
    elif "shooting" in row["Details"]:
        gun += 1
        y2011wv.loc[i, "WeapType"] = "gun"
        
    elif "knife" in row["Details"]:
        knife += 1
        y2011wv.loc[i, "WeapType"] = "knife"
        
    elif "stabbed" in row["Details"]:
        knife += 1
        y2011wv.loc[i, "WeapType"] = "knife"
        
    elif "stab" in row["Details"]:
        knife += 1
        y2011wv.loc[i, "WeapType"] = "knife"
        
    elif "cut" in row["Details"]:
        knife += 1
        y2011wv.loc[i, "WeapType"] = "knife"
        
    else:
        print(row["Details"])
        print("\n")
        
print(knife)
print(gun)

VioType.loc['Gun', 'Amount for 2011'] = gun
VioType.loc['Knife', 'Amount for 2011'] = knife

VioType
# Out:
# An officer was dispatched to Brule Street on the city’s west side last week after two vehicles were found to be damaged. A pickup truck had a rear window broken out by an apparent BB. It had been parked in a driveway. A car parked in the street had a small nick in the driver's side window which also was thought to be caused by a BB.
#
#
# ...

# %%
knife = 0
gun = 0

for i, row in y2010wv.iterrows():
    #print(row["Details"])
    #print("\n")
    
    if "gun" in row["Details"]:
        gun += 1
        y2010wv.loc[i, "WeapType"] = "gun"
        
    elif "shots" in row["Details"]:
        gun += 1
        y2010wv.loc[i, "WeapType"] = "gun"
        
    elif "shot" in row["Details"]:
        gun += 1
        y2010wv.loc[i, "WeapType"] = "gun"
        
    elif "fired" in row["Details"]:
        gun += 1
        y2010wv.loc[i, "WeapType"] = "gun"
        
    elif "shooting" in row["Details"]:
        gun += 1
        y2010wv.loc[i, "WeapType"] = "gun"
        
    elif "knife" in row["Details"]:
        knife += 1
        y2010wv.loc[i, "WeapType"] = "knife"
        
    elif "stabbed" in row["Details"]:
        knife += 1
        y2010wv.loc[i, "WeapType"] = "knife"
        
    elif "stab" in row["Details"]:
        knife += 1
        y2010wv.loc[i, "WeapType"] = "knife"
        
    elif "cut" in row["Details"]:
        knife += 1
        y2010wv.loc[i, "WeapType"] = "knife"
        
    else:
        print(row["Details"])
        print("\n")
        
print(knife)
print(gun)

VioType.loc['Gun', 'Amount for 2010'] = gun
VioType.loc['Knife', 'Amount for 2010'] = knife

VioType
# Out:
# It was nearing bar time, and a 22-year old downtown resident was in his home, with friends, trying to watch TV. His residence is next to the Red Shed tavern and very near Wando's Bar and Grill. At that time of the morning, patrons begin spilling out onto the sidewalk, and it can be rather noisy. Not the type of atmosphere which makes for good TV watching, particularly on a warm night with windows open.  The 22-year old yelled out for people to quiet down. One reveler did not take kindly to the order, and yelled back about something about grabbing a rock and throwing it threw the window. This ignited an exchange of words that elevated to the point where the 22-year old grabbed his bow and arrow and headed out to the street to confront the other man. This was disturbing to some of the bar time crowd, and two passersby contacted a nearby officer, voicing concern over the situation. The officer upholstered his service weapon and ordered the 22-year old to drop the bow and arrow. The susp
# ...

# %%
knife = 0
gun = 0

for i, row in y2008wv.iterrows():
    #print(row["Details"])
    #print("\n")
    
    if "gun" in row["Details"]:
        gun += 1
        y2008wv.loc[i, "WeapType"] = "gun"
        
    elif "shots" in row["Details"]:
        gun += 1
        y2008wv.loc[i, "WeapType"] = "gun"
        
    elif "shot" in row["Details"]:
        gun += 1
        y2008wv.loc[i, "WeapType"] = "gun"
        
    elif "fired" in row["Details"]:
        gun += 1
        y2008wv.loc[i, "WeapType"] = "gun"
        
    elif "shooting" in row["Details"]:
        gun += 1
        y2008wv.loc[i, "WeapType"] = "gun"
        
    elif "knife" in row["Details"]:
        knife += 1
        y2008wv.loc[i, "WeapType"] = "knife"
        
    elif "stabbed" in row["Details"]:
        knife += 1
        y2008wv.loc[i, "WeapType"] = "knife"
        
    elif "stab" in row["Details"]:
        knife += 1
        y2008wv.loc[i, "WeapType"] = "knife"
        
    elif "cut" in row["Details"]:
        knife += 1
        y2008wv.loc[i, "WeapType"] = "knife"
        
    else:
        print(row["Details"])
        print("\n")
        
print(knife)
print(gun)

VioType.loc['Gun', 'Amount for 2008'] = gun
VioType.loc['Knife', 'Amount for 2008'] = knife

VioType
# Out:
# A subject was injured by another with an unconfirmed object.  Appears to be an isolated incident with no additional threat to the community.  Injuries sustained are non-life threatening.
#
#
# At the above date and time MPD was sent to the above area regarding a disturbance. While checking the area, officers were approached by WALLACE who stated the above individuals had robbed him of his wallet and battered him. A search for the suspects met with negative results. WALLACE was conveyed to a friends house on Monroe Street, and soon afterwards, MPD was summoned to a location 2 blocks from the drop off site, to a traffic accident where WALLACE had a crash and rolled his vehicle. WALLACE was arrested for his 2nd OMVWI offense as a result. Investigation continues.
#
#
# ...

# %%
knife = 0
gun = 0

for i, row in y2009wv.iterrows():
#     print(i)
#     print(row["Details"])
#     print(type(row["Details"]))
#     print("\n")

    if isinstance(row["Details"], str) == False:
        continue
    
    if "gun" in row["Details"]:
        gun += 1
        y2009wv.loc[i, "WeapType"] = "gun"
        
    elif "shots" in row["Details"]:
        gun += 1
        y2009wv.loc[i, "WeapType"] = "gun"
        
    elif "shot" in row["Details"]:
        gun += 1
        y2009wv.loc[i, "WeapType"] = "gun"
        
    elif "fired" in row["Details"]:
        gun += 1
        y2009wv.loc[i, "WeapType"] = "gun"
        
    elif "shooting" in row["Details"]:
        gun += 1
        y2009wv.loc[i, "WeapType"] = "gun"
        
    elif "knife" in row["Details"]:
        knife += 1
        y2009wv.loc[i, "WeapType"] = "knife"
        
    elif "stabbed" in row["Details"]:
        knife += 1
        y2009wv.loc[i, "WeapType"] = "knife"
        
    elif "stab" in row["Details"]:
        knife += 1
        y2009wv.loc[i, "WeapType"] = "knife"
        
    elif "cut" in row["Details"]:
        knife += 1
        y2009wv.loc[i, "WeapType"] = "knife"
        
    else:
        print(row["Details"])
        print("\n")
        
print(knife)
print(gun)

VioType.loc['Gun', 'Amount for 2009'] = gun
VioType.loc['Knife', 'Amount for 2009'] = knife

VioType
# Out:
# On Sunday night, around 11:30 p.m., Madison Police pulled over Ford Explorer in the 6700 block of Schroeder Road after it was observed traveling without its headlights on. The driver pulled over, and a passenger (suspect Riccardo Simms) fled from the SUV. He ran through several backyards, and over a fence. Officers set up a perimeter and were able to take him into custody. The driver (Carlos Wilson) was also arrested. Found inside a canvas tent bag on the backseat of the Explorer was a loaded Chinese made Norinco SKS rifle with collapsible stock, a pistol grip, and pop-up sights. The driver was also found to be in possession of cocaine.
#
#
# ...

# %%
# slight redo of table

data = [['Gun', 0], ['Knife', 0]] 
VioType2 = pandas.DataFrame(data, columns = ['Type', 'Amount for 2008'])
VioType2.set_index('Type', inplace = True)

VioType2['Amount for 2008'] = VioType['Amount for 2008']
VioType2['Amount for 2009'] = VioType['Amount for 2009']
VioType2['Amount for 2010'] = VioType['Amount for 2010']
VioType2['Amount for 2011'] = VioType['Amount for 2011']
VioType2['Amount for 2012'] = VioType['Amount for 2012']
VioType2['Amount for 2013'] = VioType['Amount for 2013']
VioType2['Amount for 2014'] = VioType['Amount for 2014']
VioType2['Amount for 2015'] = VioType['Amount for 2015']
VioType2['Amount for 2016'] = VioType['Amount for 2016']
VioType2['Amount for 2017'] = VioType['Amount for 2017']
VioType2['Amount for 2018'] = VioType['Amount for 2018']

VioType2
# Out:
#        Amount for 2008  Amount for 2009  Amount for 2010  Amount for 2011  \
# Type
# Gun                 43               71               78               65
# Knife               14               19               27               33
#
#        Amount for 2012  Amount for 2013  Amount for 2014  Amount for 2015  \
# Type
# Gun                 94               94               86              125
# Knife               31               29               21               22
#
#        Amount for 2016  Amount for 2017  Amount for 2018
# Type
# Gun                131              172              168
# Knife               26               26               43

# %%
VioType2 = VioType2.transpose()

# %%
axVioType = VioType2.plot.line(y = ['Gun', 'Knife'], figsize=(20,10))

axVioType

# %%
# map animation
# clean up data, make more column
# find locality in area

y2018wv
# Out:
#           IncidentType              IncidentDate  \
# 0    Weapons Violation  2018-08-19T21:47:00.000Z
# 1    Weapons Violation  2018-01-01T01:13:00.000Z
# 2    Weapons Violation  2018-01-02T18:46:00.000Z
# 3    Weapons Violation  2018-01-02T11:55:00.000Z
# 4    Weapons Violation  2018-01-09T20:08:00.000Z
# 5    Weapons Violation  2018-01-09T21:35:00.000Z
# 6    Weapons Violation  2018-01-17T23:51:00.000Z
# 7    Weapons Violation  2018-01-18T02:34:00.000Z
# 8    Weapons Violation  2018-01-17T15:04:00.000Z
# 9    Weapons Violation  2018-01-18T21:52:00.000Z
# 10   Weapons Violation  2018-01-21T18:10:00.000Z
# 11   Weapons Violation  2018-01-22T03:37:00.000Z
# 12   Weapons Violation  2018-01-26T01:50:00.000Z
# 13   Weapons Violation  2018-01-26T23:05:00.000Z
# 14   Weapons Violation  2018-01-31T22:58:00.000Z
# 15   Weapons Violation  2018-02-02T15:30:00.000Z
# 16   Weapons Violation  2018-02-02T19:18:00.000Z
# 17   Weapons Violation  2018-02-03T00:13:00.000Z
# ...

# %%
tempfile2018 = pandas.read_csv("WeaponVio2018.csv")

for i, row in tempfile2018.iterrows():
    tempfile2018.loc[i, "WeapType"] = y2018wv.loc[i, "WeapType"]
    tempfile2018.loc[i, "Date"] = y2018wv.loc[i, "IncidentDate"]

tempfile2018
# Out:
#                                 Address  \
# 0             5100 block Great Gray Dr.
# 1                1700 block Fordem Ave.
# 2                 4300 block Green Ave.
# 3                        702 Pflaum Rd.
# 4                  4200 block School Rd
# 5               7000 block Carnwood Rd.
# 6                  4500 block Onyx Lane
# 7                           S. Park St.
# 8                  726 N. Midvale Blvd.
# 9                300 block Junction Rd.
# 10                    6200 Schroeder Rd
# 11                   211 S. Carroll St.
# 12                     200 S Bassett St
# 13                  100 blk Knutson Dr.
# 14            2000 block of Danbury St.
# 15                   211 S. Carroll St.
# 16              200 block Walter Street
# 17           2500 block Coolidge Street
# 18            1900 block South Park St.
# 19                900 block Spaight St.
# 20                           Craig Ave.
# 21                   211 S. Carroll St.
# ...

# %%
tempfile2017 = pandas.read_csv("WeaponVio2017.csv")

for i, row in tempfile2017.iterrows():
    tempfile2017.loc[i, "WeapType"] = y2017wv.loc[i, "WeapType"]
    tempfile2017.loc[i, "Date"] = y2017wv.loc[i, "IncidentDate"]

tempfile2017
# Out:
#                               Address  \
# 0            10 block Mount Vernon Ct
# 1                   900 Harrington Dr
# 2                       500 W Johnson
# 3                     East Towne Mall
# 4               2300 Upham St.(block)
# 5               6600 block Radford Dr
# 6              4500 block Bonner Lane
# 7             2222 E. Washington Ave.
# 8            6700 block Schroeder Rd.
# 9          2800 block N. Sherman Ave.
# 10               900 block Blaine Dr.
# 11       2300 block Brentwood Parkway
# 12                    West Towne Mall
# 13                 2100 block Pike Dr
# 14           3500 block Milwaukee St.
# 15             400 Block W. Gilman St
# 16           1000 East Johnson Street
# 17                7035 Littlemore Dr.
# 18           3100 block Ridgeway Ave.
# 19                      Northport Dr.
# 20                     2201 S Park St
# 21                6700 Schroeder Road
# 22                    Sherman Terrace
# ...

# %%
tempfile2016 = pandas.read_csv("WeaponVio2016.csv")

for i, row in tempfile2016.iterrows():
    tempfile2016.loc[i, "WeapType"] = y2016wv.loc[i, "WeapType"]
    tempfile2016.loc[i, "Date"] = y2016wv.loc[i, "IncidentDate"]

tempfile2016
# Out:
#                           Address  \
# 0          5700 Blk of Russett Rd
# 1      3700 Blk of E. Karstens Dr
# 2                5800 Russett Rd.
# 3                     300 Kent Ln
# 4              E. Washington Ave.
# 5    100 block W. Washington Ave.
# 6      6700 Blk of Schroeder Road
# 7        1200 block MacArthur Rd.
# 8                    Pinchot Ave.
# 9                      Monona Dr.
# 10          3800 block Nakoma Rd.
# 11               1759 Thierer Rd.
# 12     3500 block of Ridgeway Ave
# 13                  4301 Lien Rd.
# 14          2453 East Springs Dr.
# 15             600 block Vera Ct.
# 16       600 block E. Johnson St.
# 17         2200 block Carling Dr.
# 18      1800 block Helene Parkway
# 19                  National Ave.
# 20               1754 Thierer Rd.
# 21          4600 block Verona Rd.
# 22                 Steensland Dr.
# 23             6718 Park Ridge Dr
# 24                East Towne Mall
# 25         6500 block Raymond Rd.
# ...

# %%
tempfile2015 = pandas.read_csv("WeaponVio2015.csv")

for i, row in tempfile2015.iterrows():
    tempfile2015.loc[i, "WeapType"] = y2015wv.loc[i, "WeapType"]
    tempfile2015.loc[i, "Date"] = y2015wv.loc[i, "IncidentDate"]

tempfile2015
# Out:
#                               Address  \
# 0              1800 Block Helene Pkwy
# 1          3100 block Worthington Ave
# 2                      13 Collins Ct.
# 3                     1800 Fordem Ave
# 4            2300 block Columbus Lane
# 5               700 block S Gammon Rd
# 6               4600 block Verona Rd.
# 7             400 block W. Gilman St.
# 8             1100 block Moorland Rd.
# 9                     5602 Tokay Blvd
# 10             5800 block Russett Rd.
# 11                          Trailsway
# 12                  3521 Anderson St.
# 13            4700 block Crescent Rd.
# 14                 66 West Towne Mall
# 15             6800 block Chelsea St.
# 16          7200 block Longmeadow Dr.
# 17              800 block Brandie Rd.
# 18             1000 block Gammon Lane
# 19              4600 block Hayes Road
# 20                     4333 Britta Dr
# 21            1500 block Langley Lane
# 22                   317 N Bassett St
# ...

# %%
tempfile2014 = pandas.read_csv("WeaponVio2014.csv")

for i, row in tempfile2014.iterrows():
    tempfile2014.loc[i, "WeapType"] = y2014wv.loc[i, "WeapType"]
    tempfile2014.loc[i, "Date"] = y2014wv.loc[i, "IncidentDate"]

tempfile2014
# Out:
#                              Address  \
# 0       2200 block Independence Lane
# 1                     4601 Verona Rd
# 2          5200 block Piccadilly Dr.
# 3          200 block Kennedy Heights
# 4    Whitney Way near Hammersley Ave
# 5               3014 Worthington Ave
# 6                     1866 Fisher St
# 7            Lien Rd @ N Thompson Dr
# 8                   East Towne Blvd.
# 9          2000 block Westbrook Lane
# 10            400 block N Frances St
# 11             2100 block Fisher St.
# 12                 6731 Park Edge Dr
# 13                  3329 Chicago Ave
# 14                   1221 Huxley St.
# 15            1300 block Temkin Ave.
# 16                    S. Whitney Way
# 17           900 block Magnolia Lane
# 18          500 block N. Frances St.
# 19             2300 block Allied Dr.
# 20          6700 block Schroeder Rd.
# 21                     Sunfish Court
# 22            5800 block Russett Rd.
# 23                   4501 Verona Rd.
# ...

# %%
tempfile2013 = pandas.read_csv("WeaponVio2013.csv")

for i, row in tempfile2013.iterrows():
    tempfile2013.loc[i, "WeapType"] = y2013wv.loc[i, "WeapType"]
    tempfile2013.loc[i, "Date"] = y2013wv.loc[i, "IncidentDate"]

tempfile2013
# Out:
#                               Address  \
# 0                  1600 Wright Street
# 1                3100 block Meier Rd.
# 2                     2300 Carling Dr
# 3            5555 High Crossing Blvd.
# 4                       114 State St.
# 5    Traceway Dr./Turbot Dr./Pike Dr.
# 6                     2600 Ardsley Ci
# 7                     6126 Hammersley
# 8                     West Towne Mall
# 9                      121 W. Main St
# 10                       Ashford Lane
# 11              800 block Wheeler Rd.
# 12                    East Towne Mall
# 13                     7400 Tree Lane
# 14     300 block Clyde Gallagher Ave.
# 15                600 block North St.
# 16               2400 block Hoard St.
# 17             4300 block Melody Lane
# 18                600 block Buick St.
# 19              2000 block Scott Lane
# 20               900 block Emerald St
# 21               4500 block Verona Rd
# 22                 909 Chapel Hill Rd
# ...

# %%
tempfile2012 = pandas.read_csv("WeaponVio2012.csv")

for i, row in tempfile2012.iterrows():
    tempfile2012.loc[i, "WeapType"] = y2012wv.loc[i, "WeapType"]
    tempfile2012.loc[i, "Date"] = y2012wv.loc[i, "IncidentDate"]

tempfile2012
# Out:
#                                                Address  \
# 0                                      117 State St  -
# 1                           2900 Blk of Maple Grove Dr
# 2                       5300 Blk of High Crossing Blvd
# 3                                800 E. Mifflin Street
# 4                                800 Williamson Street
# 5               433 S. Gammon Rd. (Denny's restaurant)
# 6    700 block S. Gammon Road (parking lot outside ...
# 7            701 E. Washington Ave. (High Noon Saloon)
# 8    322 W. Johnson St. (Logan's Madtown restaurant...
# 9                                         McDivitt Rd.
# 10              633 S. Gammon Rd. (Wendy's restaurant)
# 11                              7100 block Flower Lane
# 12                              500 block Moorland Rd.
# 13                                3300 block Wells Ave
# 14                                       Schroeder Rd.
# 15                                     N. Thompson Dr.
# ...

# %%
tempfile2011 = pandas.read_csv("WeaponVio2011.csv")

for i, row in tempfile2011.iterrows():
    tempfile2011.loc[i, "WeapType"] = y2011wv.loc[i, "WeapType"]
    tempfile2011.loc[i, "Date"] = y2011wv.loc[i, "IncidentDate"]

tempfile2011
# Out:
#                                                Address  \
# 0                              3700 block Speedway Rd.
# 1                            3000 Block of Darbo Drive
# 2                                       1129 S Park St
# 3                              5700 block Russett Road
# 4                       Verona Road near Midvale Blvd.
# 5                                    4400 Doe Crossing
# 6                    3030 Darbo Drive (Salvation Army)
# 7                                       N. Park Street
# 8                                1800 block Helene Pky
# 9                                 500 block Oak Street
# 10                                     2201 S. Park St
# 11                    311 East Campus Mall (Walgreens)
# 12                               400 block N. Lake St.
# 13                                     1821 S. Park St
# 14                                        Brule Street
# 15                                 1300 blk. Debra La,
# ...

# %%
tempfile2010 = pandas.read_csv("WeaponVio2010.csv")

for i, row in tempfile2010.iterrows():
    tempfile2010.loc[i, "WeapType"] = y2010wv.loc[i, "WeapType"]
    tempfile2010.loc[i, "Date"] = y2010wv.loc[i, "IncidentDate"]

tempfile2010
# Out:
#                                        Address  \
# 0                         6205 Hammersley Road
# 1                          2121 East Spring Dr
# 2                  400 block W. Johnson Street
# 3                  400 block W. Johnson Street
# 4                     1000 block Regent Street
# 5    702 Pflaum Road (La Follette High School)
# 6                      400 block W. Gilman St.
# 7                            100 blk State  St
# 8                    Ohio Ave. @ St. Paul Ave.
# 9                     900 block Spaight Street
# 10            8102 Excelsior Dr. (Baymont Inn)
# 11                   3000 Block of Harriman La
# 12                           N. Fair Oaks Ave.
# 13                Ten block of East Gilman St.
# 14                          1700 Niemann Place
# 15                         1210 Williamson St.
# 16                         6700 W Beltline Hwy
# 17                 1300 block N. Stoughton Rd.
# 18                   4300 block Beilfuss Drive
# ...

# %%
tempfile2009 = pandas.read_csv("WeaponVio2009.csv")

for i, row in tempfile2009.iterrows():
    tempfile2009.loc[i, "WeapType"] = y2009wv.loc[i, "WeapType"]
    tempfile2009.loc[i, "Date"] = y2009wv.loc[i, "IncidentDate"]

tempfile2009
# Out:
#                                               Address  \
# 0                                    800 Brandie Road
# 1                             2400 block Allied Drive
# 2   4710 East Towne Blvd. (Applebee's Neighborhod ...
# 3            1745 Parkside Drive (Old Country Buffet)
# 4                                 1100 Bl Moorland Rd
# 5                            1900 block E. Mifflin St
# 6    221 Meadowlark Drive (Kennedy Elementary School)
# 7                              2400 Bl Commercial Ave
# 8                              10 East Mifflin Street
# 9                                       525 W Johnson
# 10                           6600 block Schroeder Rd.
# 11                        West Towne Mall parking lot
# 12                4202 East Towne Blvd. (Baymont Inn)
# 13                         Dempsey Road, Dawes Street
# 14        5405 Flad Avenue (St. Maria Goretti School)
# 15                             East Washington Avenue
# ...

# %%
tempfile2008 = pandas.read_csv("WeaponVio2008.csv")

for i, row in tempfile2008.iterrows():
    tempfile2008.loc[i, "WeapType"] = y2008wv.loc[i, "WeapType"]
    tempfile2008.loc[i, "Date"] = y2008wv.loc[i, "IncidentDate"]

tempfile2008
# Out:
#                                               Address  \
# 0                                 2217 Cypress Way #4
# 1                                    500 West Mifflin
# 2                                 2302 Packers Avenue
# 3                            800 block Spaight Street
# 4                                2709 W. Beltline Hwy
# 5                         1900 block of Cameron Drive
# 6                               400 Blk of S. Park St
# 7                                      1709 Monroe St
# 8                               300 block Garnet Lane
# 9                            Turbot Drive & Post Road
# 10                          2900 block Traceway Drive
# 11             322 West Johnson St. (Angelic Brewery)
# 12                                    Bram/Baird Sts.
# 13                            5700 block Raymond Road
# 14                      400 block North Murray Street
# 15  700 block of State Street (UPDATED MONDAY JUNE...
# ...

# %%
# tempfile2018.to_csv("NewWeaponVio2018.csv", encoding = 'utf-8', index = False)
# tempfile2017.to_csv("NewWeaponVio2017.csv", encoding = 'utf-8', index = False)
# tempfile2016.to_csv("NewWeaponVio2016.csv", encoding = 'utf-8', index = False)
# tempfile2015.to_csv("NewWeaponVio2015.csv", encoding = 'utf-8', index = False)
# tempfile2014.to_csv("NewWeaponVio2014.csv", encoding = 'utf-8', index = False)
# tempfile2013.to_csv("NewWeaponVio2013.csv", encoding = 'utf-8', index = False)
# tempfile2012.to_csv("NewWeaponVio2012.csv", encoding = 'utf-8', index = False)
# tempfile2011.to_csv("NewWeaponVio2011.csv", encoding = 'utf-8', index = False)
# tempfile2010.to_csv("NewWeaponVio2010.csv", encoding = 'utf-8', index = False)
# tempfile2009.to_csv("NewWeaponVio2009.csv", encoding = 'utf-8', index = False)
# tempfile2008.to_csv("NewWeaponVio2008.csv", encoding = 'utf-8', index = False)

# %%
for i, row in tempfile2018.iterrows():
    newStr = row["Date"][:7]
    
    if newStr == "2018-01":
        tempfile2018.loc[i, "Month"] = "Jan"
    elif newStr == "2018-02":
        tempfile2018.loc[i, "Month"] = "Feb"
    elif newStr == "2018-03":
        tempfile2018.loc[i, "Month"] = "Mar"
    elif newStr == "2018-04":
        tempfile2018.loc[i, "Month"] = "Apr"
    elif newStr == "2018-05":
        tempfile2018.loc[i, "Month"] = "May"
    elif newStr == "2018-06":
        tempfile2018.loc[i, "Month"] = "Jun"
    elif newStr == "2018-07":
        tempfile2018.loc[i, "Month"] = "Jul"
    elif newStr == "2018-08":
        tempfile2018.loc[i, "Month"] = "Aug"
    elif newStr == "2018-09":
        tempfile2018.loc[i, "Month"] = "Sep"
    elif newStr == "2018-10":
        tempfile2018.loc[i, "Month"] = "Oct"
    elif newStr == "2018-11":
        tempfile2018.loc[i, "Month"] = "Nov"
    elif newStr == "2018-12":
        tempfile2018.loc[i, "Month"] = "Dec"

# %%
for i, row in tempfile2017.iterrows():
    newStr = row["Date"][:7]
    
    if newStr == "2017-01":
        tempfile2017.loc[i, "Month"] = "Jan"
    elif newStr == "2017-02":
        tempfile2017.loc[i, "Month"] = "Feb"
    elif newStr == "2017-03":
        tempfile2017.loc[i, "Month"] = "Mar"
    elif newStr == "2017-04":
        tempfile2017.loc[i, "Month"] = "Apr"
    elif newStr == "2017-05":
        tempfile2017.loc[i, "Month"] = "May"
    elif newStr == "2017-06":
        tempfile2017.loc[i, "Month"] = "Jun"
    elif newStr == "2017-07":
        tempfile2017.loc[i, "Month"] = "Jul"
    elif newStr == "2017-08":
        tempfile2017.loc[i, "Month"] = "Aug"
    elif newStr == "2017-09":
        tempfile2017.loc[i, "Month"] = "Sep"
    elif newStr == "2017-10":
        tempfile2017.loc[i, "Month"] = "Oct"
    elif newStr == "2017-11":
        tempfile2017.loc[i, "Month"] = "Nov"
    elif newStr == "2017-12":
        tempfile2017.loc[i, "Month"] = "Dec"


for i, row in tempfile2016.iterrows():
    newStr = row["Date"][:7]
    
    if newStr == "2016-01":
        tempfile2016.loc[i, "Month"] = "Jan"
    elif newStr == "2016-02":
        tempfile2016.loc[i, "Month"] = "Feb"
    elif newStr == "2016-03":
        tempfile2016.loc[i, "Month"] = "Mar"
    elif newStr == "2016-04":
        tempfile2016.loc[i, "Month"] = "Apr"
    elif newStr == "2016-05":
        tempfile2016.loc[i, "Month"] = "May"
    elif newStr == "2016-06":
        tempfile2016.loc[i, "Month"] = "Jun"
    elif newStr == "2016-07":
        tempfile2016.loc[i, "Month"] = "Jul"
    elif newStr == "2016-08":
        tempfile2016.loc[i, "Month"] = "Aug"
    elif newStr == "2016-09":
        tempfile2016.loc[i, "Month"] = "Sep"
    elif newStr == "2016-10":
        tempfile2016.loc[i, "Month"] = "Oct"
    elif newStr == "2016-11":
        tempfile2016.loc[i, "Month"] = "Nov"
    elif newStr == "2016-12":
        tempfile2016.loc[i, "Month"] = "Dec"


for i, row in tempfile2015.iterrows():
    newStr = row["Date"][:7]
    
    if newStr == "2015-01":
        tempfile2015.loc[i, "Month"] = "Jan"
    elif newStr == "2015-02":
        tempfile2015.loc[i, "Month"] = "Feb"
    elif newStr == "2015-03":
        tempfile2015.loc[i, "Month"] = "Mar"
    elif newStr == "2015-04":
        tempfile2015.loc[i, "Month"] = "Apr"
    elif newStr == "2015-05":
        tempfile2015.loc[i, "Month"] = "May"
    elif newStr == "2015-06":
        tempfile2015.loc[i, "Month"] = "Jun"
    elif newStr == "2015-07":
        tempfile2015.loc[i, "Month"] = "Jul"
    elif newStr == "2015-08":
        tempfile2015.loc[i, "Month"] = "Aug"
    elif newStr == "2015-09":
        tempfile2015.loc[i, "Month"] = "Sep"
    elif newStr == "2015-10":
        tempfile2015.loc[i, "Month"] = "Oct"
    elif newStr == "2015-11":
        tempfile2015.loc[i, "Month"] = "Nov"
    elif newStr == "2015-12":
        tempfile2015.loc[i, "Month"] = "Dec"


for i, row in tempfile2014.iterrows():
    newStr = row["Date"][:7]
    
    if newStr == "2014-01":
        tempfile2014.loc[i, "Month"] = "Jan"
    elif newStr == "2014-02":
        tempfile2014.loc[i, "Month"] = "Feb"
    elif newStr == "2014-03":
        tempfile2014.loc[i, "Month"] = "Mar"
    elif newStr == "2014-04":
        tempfile2014.loc[i, "Month"] = "Apr"
    elif newStr == "2014-05":
        tempfile2014.loc[i, "Month"] = "May"
    elif newStr == "2014-06":
        tempfile2014.loc[i, "Month"] = "Jun"
    elif newStr == "2014-07":
        tempfile2014.loc[i, "Month"] = "Jul"
    elif newStr == "2014-08":
        tempfile2014.loc[i, "Month"] = "Aug"
    elif newStr == "2014-09":
        tempfile2014.loc[i, "Month"] = "Sep"
    elif newStr == "2014-10":
        tempfile2014.loc[i, "Month"] = "Oct"
    elif newStr == "2014-11":
        tempfile2014.loc[i, "Month"] = "Nov"
    elif newStr == "2014-12":
        tempfile2014.loc[i, "Month"] = "Dec"


for i, row in tempfile2013.iterrows():
    newStr = row["Date"][:7]
    
    if newStr == "2013-01":
        tempfile2013.loc[i, "Month"] = "Jan"
    elif newStr == "2013-02":
        tempfile2013.loc[i, "Month"] = "Feb"
    elif newStr == "2013-03":
        tempfile2013.loc[i, "Month"] = "Mar"
    elif newStr == "2013-04":
        tempfile2013.loc[i, "Month"] = "Apr"
    elif newStr == "2013-05":
        tempfile2013.loc[i, "Month"] = "May"
    elif newStr == "2013-06":
        tempfile2013.loc[i, "Month"] = "Jun"
    elif newStr == "2013-07":
        tempfile2013.loc[i, "Month"] = "Jul"
    elif newStr == "2013-08":
        tempfile2013.loc[i, "Month"] = "Aug"
    elif newStr == "2013-09":
        tempfile2013.loc[i, "Month"] = "Sep"
    elif newStr == "2013-10":
        tempfile2013.loc[i, "Month"] = "Oct"
    elif newStr == "2013-11":
        tempfile2013.loc[i, "Month"] = "Nov"
    elif newStr == "2013-12":
        tempfile2013.loc[i, "Month"] = "Dec"


for i, row in tempfile2012.iterrows():
    newStr = row["Date"][:7]
    
    if newStr == "2012-01":
        tempfile2012.loc[i, "Month"] = "Jan"
    elif newStr == "2012-02":
        tempfile2012.loc[i, "Month"] = "Feb"
    elif newStr == "2012-03":
        tempfile2012.loc[i, "Month"] = "Mar"
    elif newStr == "2012-04":
        tempfile2012.loc[i, "Month"] = "Apr"
    elif newStr == "2012-05":
        tempfile2012.loc[i, "Month"] = "May"
    elif newStr == "2012-06":
        tempfile2012.loc[i, "Month"] = "Jun"
    elif newStr == "2012-07":
        tempfile2012.loc[i, "Month"] = "Jul"
    elif newStr == "2012-08":
        tempfile2012.loc[i, "Month"] = "Aug"
    elif newStr == "2012-09":
        tempfile2012.loc[i, "Month"] = "Sep"
    elif newStr == "2012-10":
        tempfile2012.loc[i, "Month"] = "Oct"
    elif newStr == "2012-11":
        tempfile2012.loc[i, "Month"] = "Nov"
    elif newStr == "2012-12":
        tempfile2012.loc[i, "Month"] = "Dec"


for i, row in tempfile2011.iterrows():
    newStr = row["Date"][:7]
    
    if newStr == "2011-01":
        tempfile2011.loc[i, "Month"] = "Jan"
    elif newStr == "2011-02":
        tempfile2011.loc[i, "Month"] = "Feb"
    elif newStr == "2011-03":
        tempfile2011.loc[i, "Month"] = "Mar"
    elif newStr == "2011-04":
        tempfile2011.loc[i, "Month"] = "Apr"
    elif newStr == "2011-05":
        tempfile2011.loc[i, "Month"] = "May"
    elif newStr == "2011-06":
        tempfile2011.loc[i, "Month"] = "Jun"
    elif newStr == "2011-07":
        tempfile2011.loc[i, "Month"] = "Jul"
    elif newStr == "2011-08":
        tempfile2011.loc[i, "Month"] = "Aug"
    elif newStr == "2011-09":
        tempfile2011.loc[i, "Month"] = "Sep"
    elif newStr == "2011-10":
        tempfile2011.loc[i, "Month"] = "Oct"
    elif newStr == "2011-11":
        tempfile2011.loc[i, "Month"] = "Nov"
    elif newStr == "2011-12":
        tempfile2011.loc[i, "Month"] = "Dec"


for i, row in tempfile2010.iterrows():
    newStr = row["Date"][:7]
    
    if newStr == "2010-01":
        tempfile2010.loc[i, "Month"] = "Jan"
    elif newStr == "2010-02":
        tempfile2010.loc[i, "Month"] = "Feb"
    elif newStr == "2010-03":
        tempfile2010.loc[i, "Month"] = "Mar"
    elif newStr == "2010-04":
        tempfile2010.loc[i, "Month"] = "Apr"
    elif newStr == "2010-05":
        tempfile2010.loc[i, "Month"] = "May"
    elif newStr == "2010-06":
        tempfile2010.loc[i, "Month"] = "Jun"
    elif newStr == "2010-07":
        tempfile2010.loc[i, "Month"] = "Jul"
    elif newStr == "2010-08":
        tempfile2010.loc[i, "Month"] = "Aug"
    elif newStr == "2010-09":
        tempfile2010.loc[i, "Month"] = "Sep"
    elif newStr == "2010-10":
        tempfile2010.loc[i, "Month"] = "Oct"
    elif newStr == "2010-11":
        tempfile2010.loc[i, "Month"] = "Nov"
    elif newStr == "2010-12":
        tempfile2010.loc[i, "Month"] = "Dec"


for i, row in tempfile2009.iterrows():
    newStr = row["Date"][:7]
    
    if newStr == "2009-01":
        tempfile2009.loc[i, "Month"] = "Jan"
    elif newStr == "2009-02":
        tempfile2009.loc[i, "Month"] = "Feb"
    elif newStr == "2009-03":
        tempfile2009.loc[i, "Month"] = "Mar"
    elif newStr == "2009-04":
        tempfile2009.loc[i, "Month"] = "Apr"
    elif newStr == "2009-05":
        tempfile2009.loc[i, "Month"] = "May"
    elif newStr == "2009-06":
        tempfile2009.loc[i, "Month"] = "Jun"
    elif newStr == "2009-07":
        tempfile2009.loc[i, "Month"] = "Jul"
    elif newStr == "2009-08":
        tempfile2009.loc[i, "Month"] = "Aug"
    elif newStr == "2009-09":
        tempfile2009.loc[i, "Month"] = "Sep"
    elif newStr == "2009-10":
        tempfile2009.loc[i, "Month"] = "Oct"
    elif newStr == "2009-11":
        tempfile2009.loc[i, "Month"] = "Nov"
    elif newStr == "2009-12":
        tempfile2009.loc[i, "Month"] = "Dec"


for i, row in tempfile2008.iterrows():
    newStr = row["Date"][:7]
    
    if newStr == "2008-01":
        tempfile2008.loc[i, "Month"] = "Jan"
    elif newStr == "2008-02":
        tempfile2008.loc[i, "Month"] = "Feb"
    elif newStr == "2008-03":
        tempfile2008.loc[i, "Month"] = "Mar"
    elif newStr == "2008-04":
        tempfile2008.loc[i, "Month"] = "Apr"
    elif newStr == "2008-05":
        tempfile2008.loc[i, "Month"] = "May"
    elif newStr == "2008-06":
        tempfile2008.loc[i, "Month"] = "Jun"
    elif newStr == "2008-07":
        tempfile2008.loc[i, "Month"] = "Jul"
    elif newStr == "2008-08":
        tempfile2008.loc[i, "Month"] = "Aug"
    elif newStr == "2008-09":
        tempfile2008.loc[i, "Month"] = "Sep"
    elif newStr == "2008-10":
        tempfile2008.loc[i, "Month"] = "Oct"
    elif newStr == "2008-11":
        tempfile2008.loc[i, "Month"] = "Nov"
    elif newStr == "2008-12":
        tempfile2008.loc[i, "Month"] = "Dec"

# %% [markdown]
# tempfile2008

# %%
tempfile2010
# Out:
#                                        Address  \
# 0                         6205 Hammersley Road
# 1                          2121 East Spring Dr
# 2                  400 block W. Johnson Street
# 3                  400 block W. Johnson Street
# 4                     1000 block Regent Street
# 5    702 Pflaum Road (La Follette High School)
# 6                      400 block W. Gilman St.
# 7                            100 blk State  St
# 8                    Ohio Ave. @ St. Paul Ave.
# 9                     900 block Spaight Street
# 10            8102 Excelsior Dr. (Baymont Inn)
# 11                   3000 Block of Harriman La
# 12                           N. Fair Oaks Ave.
# 13                Ten block of East Gilman St.
# 14                          1700 Niemann Place
# 15                         1210 Williamson St.
# 16                         6700 W Beltline Hwy
# 17                 1300 block N. Stoughton Rd.
# 18                   4300 block Beilfuss Drive
# ...

# %%
tempfile2018.to_csv("NewWeaponVio2018.csv", encoding = 'utf-8', index = False)
tempfile2017.to_csv("NewWeaponVio2017.csv", encoding = 'utf-8', index = False)
tempfile2016.to_csv("NewWeaponVio2016.csv", encoding = 'utf-8', index = False)
tempfile2015.to_csv("NewWeaponVio2015.csv", encoding = 'utf-8', index = False)
tempfile2014.to_csv("NewWeaponVio2014.csv", encoding = 'utf-8', index = False)
tempfile2013.to_csv("NewWeaponVio2013.csv", encoding = 'utf-8', index = False)
tempfile2012.to_csv("NewWeaponVio2012.csv", encoding = 'utf-8', index = False)
tempfile2011.to_csv("NewWeaponVio2011.csv", encoding = 'utf-8', index = False)
tempfile2010.to_csv("NewWeaponVio2010.csv", encoding = 'utf-8', index = False)
tempfile2009.to_csv("NewWeaponVio2009.csv", encoding = 'utf-8', index = False)
tempfile2008.to_csv("NewWeaponVio2008.csv", encoding = 'utf-8', index = False)
